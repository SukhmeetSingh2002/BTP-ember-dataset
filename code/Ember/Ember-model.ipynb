# %% [markdown]
# # Final Features extracted

# %% [markdown]
# - label: This feature indicates whether the file is labeled as benign (False) or malicious (True).
# - .textsize: This feature represents the size of the .text section in the PE file.
# - .textentropy: This feature represents the entropy of the .text section in the PE file.
# - .textvsize: This feature represents the virtual size of the .text section in the PE file.
# - .datasize: This feature represents the size of the .data section in the PE file.
# - .dataentropy: This feature represents the entropy of the .data section in the PE file.
# - .datavsize: This feature represents the virtual size of the .data section in the PE file.
# - .rsrcsize: This feature represents the size of the .rsrc section in the PE file.
# - .rsrcentropy: This feature represents the entropy of the .rsrc section in the PE file.
# - .rsrcvsize: This feature represents the virtual size of the .rsrc section in the PE file.
# - machine: This feature represents the type of machine for which the file is intended.
# - subsystem: This feature represents the target subsystem for the PE file.
# - generalsize: This feature represents the size of the general file information in the PE header.
# - generalvsize: This feature represents the virtual size of the general file information in the PE header.
# - generalhas_debug: This feature indicates whether the PE file has a debug section (True) or not (False).
# - generalexports: This feature represents the number of exported functions in the PE file.
# - generalimports: This feature represents the number of imported functions in the PE file.
# - generalhas_relocations: This feature indicates whether the PE file has relocation information (True) or not (False).
# - generalhas_resources: This feature indicates whether the PE file has resource information (True) or not (False).
# - generalhas_signature: This feature indicates whether the PE file has a digital signature (True) or not (False).
# - generalhas_tls: This feature indicates whether the PE file has thread local storage (TLS) information (True) or not (False).
# - generalsymbols: This feature represents the number of symbols in the PE file.
# - stringsnumstrings: This feature represents the number of printable strings in the PE file.
# - stringsavlength: This feature represents the average length of the printable strings in the PE file.
# - stringsprintabledist: This feature represents the histogram of printable characters within the printable strings.
# - stringsprintables: This feature indicates whether the PE file contains printable strings (True) or not (False).
# - stringsentropy: This feature represents the entropy of characters across all printable strings.
# - stringspaths: This feature represents the number of strings that begin with "C:\" indicating paths.
# - stringsurls: This feature represents the number of strings that contain "http://" or "https://" indicating URLs.
# - stringsregistry: This feature represents the number of strings that contain "HKEY_" indicating registry keys.
# - stringsMZ: This feature represents the number of strings that contain "MZ" indicating Windows PE droppers or bundled executables.
# - cofftimestamp: This feature represents the timestamp in the COFF header of the PE file.
# - coffmachine: This feature represents the target machine for which the PE file is intended.
# - coffcharacteristics: This feature represents a list of image characteristics of the PE file.
# - optionalsubsystem: This feature represents the target subsystem specified in the optional header of the PE file.
# - optionaldll_characteristics: This feature represents a list of DLL characteristics of the PE file.
# - optionalmagic: This feature represents the magic value in the optional header of the PE file.
# - optionalmajor_image_version: This feature represents the major image version specified in the optional header of the PE file.
# - optionalminor_image_version: This feature represents the minor image version specified in the optional header of the PE file.
# - optionalmajor_linker_version: This feature represents the major linker version specified in the optional header of the PE file.
# - optionalminor_linker_version: This feature represents the minor linker version specified in the optional header of the PE file.
# - optionalmajor_operating_system_version: This feature represents the major operating system version specified in the optional header of the PE file.
# - optionalminor_operating_system_version: This feature represents the minor operating system version specified in the optional header of the PE file.
# - optionalmajor_subsystem_version: This feature represents the major subsystem version specified in the optional header of the PE file.
# - optionalminor_subsystem_version: This feature represents the minor subsystem version specified in the optional header of the PE file.
# - optionalsizeof_code: This feature represents the size of the code section specified in the optional header of the PE file.
# - optionalsizeof_headers: This feature represents the size of the headers specified in the optional header of the PE file.
# - optionalsizeof_heap_commit: This feature represents the size of the committed heap specified in the optional header of the PE file.

# %% [markdown]
# # Dependencies

# %%
# %pip install scikit-learn 
# %pip install matplotlib
# %pip install scipy 
# %pip install keras 
# %pip install seaborn
# %pip install tensorflow
# %pip install scikeras
# %pip instlal joblib
# %pip install pydot
# %pip install visualkeras
# Out:
# /bin/bash: /home/sukhmeet/miniconda3/envs/tf/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages (from visualkeras) (10.0.0)
# Requirement already satisfied: numpy>=1.18.1 in /home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages (from visualkeras) (1.24.3)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Obtaining dependency information for aggdraw>=1.3.11 from https://files.pythonhosted.org/packages/0d/d6/dbd0ee154329d4618280c778dee1efcdabb9397c97d79657488b328139da/aggdraw-1.3.18-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aggdraw-1.3.18-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Downloading aggdraw-1.3.18-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.3/993.3 kB 15.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.18 visualkeras-0.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
tf.test.is_built_with_cuda()
# Out:
# False

# %% [markdown]
# # Library Imports

# %%
# import all the required libraries in this place

import ember

import json
import csv
import threading
import math
import pandas as pd
import numpy as np
import multiprocessing
import random as rn

import seaborn as sns
import matplotlib.pyplot as plt



from data import data_visualization, data_loading
from models import annModels

from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report 
from sklearn.model_selection import  learning_curve
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.decomposition import PCA
from scikeras.wrappers import KerasClassifier

import xgboost as xgb

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model

import keras
from keras.models import Sequential
from keras.layers import Input, Dense, Activation, Dropout, Activation
from keras.optimizers import SGD
from keras.models import load_model
from keras import regularizers
from keras import backend as K
from keras.layers import BatchNormalization
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, Conv2D, MaxPooling2D
from keras.regularizers import l2
from keras.layers import concatenate
from sklearn.model_selection import StratifiedKFold

import joblib
# Out:
# 2024-02-19 04:33:05.074782: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-19 04:33:05.885970: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Loading  Dataset

# %% [markdown]
# ## Load from file 1

# %%
#Function to load data set
def load_dataset_from_jsonl(file_path, file_idx_start=0,file_idx_end=0,testing = False):
    dataset = []
    
    for i in range(file_idx_start,file_idx_end+1):
        path = file_path
        if not testing:
            path += '_' + str(i)
        path+= '.jsonl'
        with open(path, 'r') as file:
            for line in file:
                data = json.loads(line)
                dataset.append(data)

        if not testing:
            print('File name: ', path)
            print('Loading training data: ', len(dataset), end='\n')
    return dataset


FILE_PATH_TRAINING = '../../dataset/ember2018/train_features'
FILE_PATH_TESTING = '../../dataset/ember2018/test_features'


dataset_training = load_dataset_from_jsonl(FILE_PATH_TRAINING,0,5)
dataset_testing = load_dataset_from_jsonl(FILE_PATH_TESTING,testing=True)
# Out:
# File name:  ../../dataset/ember2018/train_features_0.jsonl
# Loading training data:  50000
# File name:  ../../dataset/ember2018/train_features_1.jsonl
# Loading training data:  208158
# File name:  ../../dataset/ember2018/train_features_2.jsonl
# Loading training data:  336049
# File name:  ../../dataset/ember2018/train_features_3.jsonl
# Loading training data:  465244
# File name:  ../../dataset/ember2018/train_features_4.jsonl
# Loading training data:  597426
# File name:  ../../dataset/ember2018/train_features_5.jsonl
# Loading training data:  800000

# %%
print("Training dataset size: ", len(dataset_training))
print("Type of dataset: ", type(dataset_training))
number_of_zero_labels = 0
number_of_one_labels = 0
number_of_negative_one_labels = 0
for data in dataset_training:
    if data['label'] == 0:
        number_of_zero_labels += 1
    elif data['label'] == 1:
        number_of_one_labels += 1
    else:
        number_of_negative_one_labels += 1
print("Number of zero labels: ", number_of_zero_labels)
print("Number of one labels: ", number_of_one_labels)
print("Number of negative one labels: ", number_of_negative_one_labels)

print("Testing dataset size: ", len(dataset_testing))

# print % of zero labels
print("Percentage of zero labels: ", number_of_zero_labels/len(dataset_training)*100)
print("Percentage of one labels: ", number_of_one_labels/len(dataset_training)*100)
print("Percentage of negative one labels: ", number_of_negative_one_labels/len(dataset_training)*100)
# Out:
# Training dataset size:  800000
# Type of dataset:  <class 'list'>
# Number of zero labels:  300000
# Number of one labels:  300000
# Number of negative one labels:  200000
# Testing dataset size:  200000
# Percentage of zero labels:  37.5
# Percentage of one labels:  37.5
# Percentage of negative one labels:  25.0

# %% [markdown]
# ## Flattening the json objects

# %%
def extract_features(feature, feature_name, features):
    
    for key, value in feature.items(): 
        
        string_name = feature_name + '_' + key
        if string_name not in features:
            features[string_name]= []
        
        if isinstance(value, int) or isinstance(value, float):
            features[string_name].append(value)
        else:
            features[string_name].append(None)
    

def extract_features_from_dataset_to_dataframe(dataset):
    
    features= {}
    features['label']=[]

    section_names = ['.text', '.data', '.rsrc']
    feature_names = ['size', 'entropy', 'vsize']

    for section in section_names:
        for feature in feature_names:
            features[section +'_' + feature] = []

    features['machine']=[]
    features['subsystem']=[]


    for data in dataset:
        
        if data['label'] == -1:
            continue

        #all sections should be equal to 1    
        section_count_list = {'.text':0, '.data':0, '.rsrc':0}
        for item in data['section']['sections']:
            
            if item['name'] in section_names:
                section_count_list[item['name']]+=1
        
        check = False
        for key,value in section_count_list.items():
            if value!=1:
                check=True
                break
        
        if check:
            continue
            
        feature_names = ['size', 'entropy', 'vsize']
            
        for item in data['section']['sections']:

            if item['name'] in section_names:
                
                for feature in feature_names:
                    val = item[feature] if item[feature]!=None else None
                    features[item['name'] + '_' + feature].append(val)
        
        feature_names = ['general', 'strings']

        for feature in feature_names:
            extract_features(data[feature], feature,features)

        for item in data['header']:
            extract_features(data['header'][item], item,features)
        
        features['machine'].append(data['header']['coff']['machine'])
        features['subsystem'].append(data['header']['optional']['subsystem'])
        
        
        features['label'].append(data['label'])

    df = pd.DataFrame(features)
    print(df['label'].value_counts())
    return df


traning_data = extract_features_from_dataset_to_dataframe(dataset_training)
testing_data = extract_features_from_dataset_to_dataframe(dataset_testing)
# Out:
# label
# 0    157725
# 1    150733
# Name: count, dtype: int64
# label
# 0    57489
# 1    52790
# Name: count, dtype: int64

# %%
df_training = traning_data
df_testing = testing_data

# %%
df_testing['subsystem'].replace('???','UNKNOWN',inplace=True)
df_training['subsystem'].replace('???','UNKNOWN',inplace=True)

# %%
for column in df_testing.columns:
  print("training",column)
  print(df_training[column].value_counts())
  print('-------\n')
  print("tesinting",column)
  print(df_testing[column].value_counts())
  print()
  print("---------------------------------------------------------------------------------------------------------\n")
# Out:
# training label
# label
# 0    157725
# 1    150733
# Name: count, dtype: int64
# -------
#
# tesinting label
# label
# 0    57489
# 1    52790
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .text_size
# .text_size
# 262144      10685
# 169984       8156
# 6656         4887
# 761856       3974
# 4096         3850
#             ...
# 20132352        1
# 4400128         1
# 12588032        1
# 3291648         1
# 5459968         1
# Name: count, Length: 10812, dtype: int64
# -------
#
# tesinting .text_size
# .text_size
# 28672      3784
# 49152      3480
# 6656       2928
# 36864      2475
# 361472     2320
#            ...
# 1797120       1
# 1808896       1
# 7929856       1
# 6318080       1
# 1980416       1
# Name: count, Length: 5848, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .text_entropy
# .text_entropy
#  6.640590    10482
#  6.719869     8112
#  6.610926     3930
#  6.191553     3534
# -0.000000     2996
#              ...
#  6.333208        1
#  6.497638        1
#  6.068958        1
#  6.284015        1
#  6.447386        1
# Name: count, Length: 160207, dtype: int64
# -------
#
# tesinting .text_entropy
# .text_entropy
# 5.801072    2971
# 6.198878    2512
# 6.142183    2297
# 6.560937    2189
# 5.801567    1684
#             ...
# 3.719104       1
# 3.503754       1
# 6.593487       1
# 2.638056       1
# 5.252698       1
# Name: count, Length: 57474, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .text_vsize
# .text_vsize
# 261943     10503
# 169476      8114
# 761122      3936
# 6552        3540
# 62020       2695
#            ...
# 64936          1
# 99984          1
# 1705746        1
# 151562         1
# 34613          1
# Name: count, Length: 106411, dtype: int64
# -------
#
# tesinting .text_vsize
# .text_vsize
# 45078     2971
# 25347     2512
# 8192      2394
# 361286    2307
# 249095    1923
#           ...
# 68028        1
# 38416        1
# 320838       1
# 17124        1
# 227522       1
# Name: count, Length: 38371, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .data_size
# .data_size
# 4096       36242
# 512        31231
# 1024       18987
# 7680       14674
# 3584       13866
#            ...
# 501248         1
# 1095680        1
# 1760256        1
# 9928704        1
# 2526720        1
# Name: count, Length: 3661, dtype: int64
# -------
#
# tesinting .data_size
# .data_size
# 4096       17897
# 512        10472
# 1024        5146
# 2048        5051
# 12288       4796
#            ...
# 1414656        1
# 209408         1
# 160107         1
# 3340800        1
# 2022912        1
# Name: count, Length: 1782, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .data_entropy
# .data_entropy
# -0.000000    33111
#  4.082739    10474
#  3.589640     8112
#  4.957800     3935
#  4.516155     2875
#              ...
#  4.133104        1
#  1.640984        1
#  3.957756        1
#  6.637066        1
#  3.481159        1
# Name: count, Length: 118716, dtype: int64
# -------
#
# tesinting .data_entropy
# .data_entropy
# -0.000000    13291
#  3.976184     2971
#  3.878122     2510
#  4.829645     2297
#  3.943844     2175
#              ...
#  1.354051        1
#  2.383624        1
#  4.984333        1
#  2.024903        1
#  2.485821        1
# Name: count, Length: 39477, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .data_vsize
# .data_vsize
# 11404       10537
# 136712       8116
# 3208         4008
# 283818       3936
# 1960         3586
#             ...
# 414685          1
# 5573360         1
# 98221           1
# 139124          1
# 67349076        1
# Name: count, Length: 39042, dtype: int64
# -------
#
# tesinting .data_vsize
# .data_vsize
# 2352      2975
# 4096      2577
# 816       2514
# 18560     2340
# 20200     1924
#           ...
# 19644        1
# 39168        1
# 381988       1
# 50916        1
# 225828       1
# Name: count, Length: 19395, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .rsrc_size
# .rsrc_size
# 1536        20772
# 4096        20231
# 1024        17329
# 512         10592
# 749568      10523
#             ...
# 5140992         1
# 5911040         1
# 48041           1
# 3148288         1
# 12926976        1
# Name: count, Length: 9747, dtype: int64
# -------
#
# tesinting .rsrc_size
# .rsrc_size
# 4096       9116
# 1024       6544
# 1536       5916
# 8192       4943
# 16384      3632
#            ...
# 1613824       1
# 6189056       1
# 7663616       1
# 7518208       1
# 982016        1
# Name: count, Length: 5225, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .rsrc_entropy
# .rsrc_entropy
# -0.000000    10559
#  5.391061    10435
#  4.706937     8072
#  3.769816     3935
#  5.067445     3534
#              ...
#  3.161820        1
#  6.749028        1
#  5.716910        1
#  4.910814        1
#  6.977566        1
# Name: count, Length: 172726, dtype: int64
# -------
#
# tesinting .rsrc_entropy
# .rsrc_entropy
# -0.000000    6760
#  7.429803    2969
#  5.083300    2509
#  4.127426    2297
#  5.554412    2175
#              ...
#  3.526517       1
#  7.793549       1
#  4.917795       1
#  7.071718       1
#  1.240644       1
# Name: count, Length: 55573, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training .rsrc_vsize
# .rsrc_vsize
# 749176     10502
# 18048       8222
# 480         4673
# 700         4398
# 36944       3959
#            ...
# 2600740        1
# 68516          1
# 3014616        1
# 1121624        1
# 192484         1
# Name: count, Length: 52116, dtype: int64
# -------
#
# tesinting .rsrc_vsize
# .rsrc_vsize
# 71324     2971
# 4096      2865
# 16064     2801
# 5532      2513
# 67444     1918
#           ...
# 24168        1
# 17634        1
# 120898       1
# 28720        1
# 43588        1
# Name: count, Length: 22545, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training machine
# machine
# I386       276242
# AMD64       31428
# ARMNT         249
# ???           205
# IA64          145
# THUMB          69
# R4000          47
# ARM            44
# POWERPC        15
# SH3             9
# SH4             4
# MIPSFPU         1
# Name: count, dtype: int64
# -------
#
# tesinting machine
# machine
# I386       103129
# AMD64        6930
# ARMNT         127
# ???            62
# IA64           10
# ARM             8
# THUMB           5
# SH3             3
# R4000           3
# POWERPC         2
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training subsystem
# subsystem
# WINDOWS_GUI                 274528
# WINDOWS_CUI                  30166
# NATIVE                        3444
# WINDOWS_CE_GUI                 183
# WINDOWS_BOOT_APPLICATION        93
# EFI_BOOT_SERVICE_DRIVER         20
# EFI_APPLICATION                 12
# UNKNOWN                         11
# POSIX_CUI                        1
# Name: count, dtype: int64
# -------
#
# tesinting subsystem
# subsystem
# WINDOWS_GUI                 102065
# WINDOWS_CUI                   7595
# NATIVE                         562
# WINDOWS_CE_GUI                  20
# WINDOWS_BOOT_APPLICATION        15
# UNKNOWN                         12
# EFI_BOOT_SERVICE_DRIVER          9
# EFI_APPLICATION                  1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_size
# general_size
# 139264     2254
# 595496     2239
# 5267459    1976
# 1130344    1295
# 1250816    1070
#            ...
# 537536        1
# 4002201       1
# 2095328       1
# 385552        1
# 298685        1
# Name: count, Length: 117996, dtype: int64
# -------
#
# tesinting general_size
# general_size
# 139264     3130
# 155648     1796
# 637992     1545
# 131200     1118
# 1250816     825
#            ...
# 836560        1
# 93022         1
# 281227        1
# 3287576       1
# 1045844       1
# Name: count, Length: 45485, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_vsize
# general_vsize
# 1134592     10652
# 360448       8763
# 28672        6037
# 32768        4345
# 217088       4249
#             ...
# 21897216        1
# 20213760        1
# 15224832        1
# 26763264        1
# 70619136        1
# Name: count, Length: 7541, dtype: int64
# -------
#
# tesinting general_vsize
# general_vsize
# 139264      3426
# 32768       3102
# 53248       3084
# 573440      2478
# 155648      2282
#             ...
# 5484544        1
# 6025216        1
# 44515328       1
# 12664832       1
# 20471808       1
# Name: count, Length: 4672, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_has_debug
# general_has_debug
# 0    156088
# 1    152370
# Name: count, dtype: int64
# -------
#
# tesinting general_has_debug
# general_has_debug
# 0    62576
# 1    47703
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_exports
# general_exports
# 0       232491
# 1        14250
# 3        11490
# 2         8178
# 4         7453
#          ...
# 1080         1
# 1122         1
# 6326         1
# 2272         1
# 4079         1
# Name: count, Length: 2524, dtype: int64
# -------
#
# tesinting general_exports
# general_exports
# 0       92154
# 1        3768
# 2        2019
# 4        1617
# 3        1522
#         ...
# 1979        1
# 169         1
# 251         1
# 4416        1
# 8923        1
# Name: count, Length: 1195, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_imports
# general_imports
# 247     13106
# 0       12818
# 137      8635
# 155      8060
# 55       5060
#         ...
# 1169        1
# 2303        1
# 2111        1
# 1545        1
# 1085        1
# Name: count, Length: 2361, dtype: int64
# -------
#
# tesinting general_imports
# general_imports
# 0       8433
# 200     4170
# 54      3301
# 55      3046
# 61      2783
#         ...
# 2275       1
# 706        1
# 1377       1
# 1676       1
# 1456       1
# Name: count, Length: 1499, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_has_relocations
# general_has_relocations
# 1    165465
# 0    142993
# Name: count, dtype: int64
# -------
#
# tesinting general_has_relocations
# general_has_relocations
# 0    63421
# 1    46858
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_has_resources
# general_has_resources
# 1    299155
# 0      9303
# Name: count, dtype: int64
# -------
#
# tesinting general_has_resources
# general_has_resources
# 1    101598
# 0      8681
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_has_signature
# general_has_signature
# 0    211053
# 1     97405
# Name: count, dtype: int64
# -------
#
# tesinting general_has_signature
# general_has_signature
# 0    84370
# 1    25909
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_has_tls
# general_has_tls
# 0    238622
# 1     69836
# Name: count, dtype: int64
# -------
#
# tesinting general_has_tls
# general_has_tls
# 0    96320
# 1    13959
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training general_symbols
# general_symbols
# 0        305397
# 3           393
# 3644        140
# 4            61
# 12403        50
#           ...
# 1256          1
# 1085          1
# 17290         1
# 1751          1
# 1226          1
# Name: count, Length: 1078, dtype: int64
# -------
#
# tesinting general_symbols
# general_symbols
# 0        108477
# 3          1121
# 10           31
# 4            28
# 29           23
#           ...
# 365           1
# 53355         1
# 22023         1
# 957           1
# 313           1
# Name: count, Length: 407, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_numstrings
# strings_numstrings
# 3312     10451
# 3753      3959
# 3348      2453
# 475       1924
# 2601      1827
#          ...
# 37454        1
# 50864        1
# 57086        1
# 75604        1
# 22649        1
# Name: count, Length: 37641, dtype: int64
# -------
#
# tesinting strings_numstrings
# strings_numstrings
# 475      3006
# 768      1706
# 493      1140
# 2244     1013
# 1255      700
#          ...
# 41100       1
# 28416       1
# 11233       1
# 56807       1
# 13846       1
# Name: count, Length: 20566, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_avlength
# strings_avlength
# 14.227368    1843
# 11.258747    1573
# 14.029948     747
# 24.930857     726
# 12.000000     627
#              ...
# 5.902266        1
# 20.065156       1
# 7.123011        1
# 21.460809       1
# 7.624108        1
# Name: count, Length: 238199, dtype: int64
# -------
#
# tesinting strings_avlength
# strings_avlength
# 14.227368    2969
# 14.029948    1684
# 8.827586     1117
# 8.159363      695
# 12.286542     611
#              ...
# 20.766208       1
# 6.856749        1
# 11.083763       1
# 8.192950        1
# 16.962420       1
# Name: count, Length: 82378, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_printabledist
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting strings_printabledist
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_printables
# strings_printables
# 6758       1848
# 29284      1575
# 10775       760
# 82571       726
# 2297        628
#            ...
# 1155558       1
# 288831        1
# 194640        1
# 123496        1
# 28152         1
# Name: count, Length: 114878, dtype: int64
# -------
#
# tesinting strings_printables
# strings_printables
# 6758     2970
# 10775    1685
# 4352     1117
# 10240     698
# 27571     611
#          ...
# 34374       1
# 68281       1
# 35795       1
# 74754       1
# 36157       1
# Name: count, Length: 57302, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_entropy
# strings_entropy
# 5.263887    1843
# 5.681257     747
# 5.178692     621
# 4.949852     595
# 5.220300     467
#             ...
# 5.595420       1
# 6.539338       1
# 5.754809       1
# 5.834127       1
# 6.051849       1
# Name: count, Length: 277026, dtype: int64
# -------
#
# tesinting strings_entropy
# strings_entropy
# 5.263887    2969
# 5.681257    1684
# 6.310628    1117
# 6.192048     695
# 5.630991     389
#             ...
# 5.844544       1
# 6.214871       1
# 5.817289       1
# 5.764762       1
# 5.754187       1
# Name: count, Length: 92103, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_paths
# strings_paths
# 0       198973
# 1        49355
# 2        25652
# 3         8984
# 4         5676
#          ...
# 591          1
# 623          1
# 1207         1
# 404          1
# 487          1
# Name: count, Length: 525, dtype: int64
# -------
#
# tesinting strings_paths
# strings_paths
# 0      70511
# 1      20313
# 2       7662
# 3       2961
# 4       1480
#        ...
# 821        1
# 202        1
# 104        1
# 343        1
# 460        1
# Name: count, Length: 326, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_urls
# strings_urls
# 0       148700
# 1        34168
# 39       11292
# 20       10324
# 2         8271
#          ...
# 810          1
# 1360         1
# 1708         1
# 497          1
# 2310         1
# Name: count, Length: 755, dtype: int64
# -------
#
# tesinting strings_urls
# strings_urls
# 0       63014
# 1       10025
# 2        3768
# 9        3241
# 20       2054
#         ...
# 496         1
# 410         1
# 420         1
# 863         1
# 1312        1
# Name: count, Length: 412, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_registry
# strings_registry
# 0      291463
# 7        4215
# 1        2848
# 4        2184
# 5        1676
#         ...
# 738         1
# 100         1
# 309         1
# 146         1
# 105         1
# Name: count, Length: 124, dtype: int64
# -------
#
# tesinting strings_registry
# strings_registry
# 0      103690
# 7        1616
# 1         873
# 5         790
# 2         599
#         ...
# 31          1
# 61          1
# 160         1
# 56          1
# 888         1
# Name: count, Length: 74, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training strings_MZ
# strings_MZ
# 1       48103
# 2       40421
# 3       37722
# 4       28203
# 8       21709
#         ...
# 984         1
# 914         1
# 960         1
# 1064        1
# 1244        1
# Name: count, Length: 1261, dtype: int64
# -------
#
# tesinting strings_MZ
# strings_MZ
# 1       16008
# 3       15034
# 2       12553
# 4       10057
# 5        7772
#         ...
# 1070        1
# 476         1
# 395         1
# 700         1
# 441         1
# Name: count, Length: 514, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training coff_timestamp
# coff_timestamp
# 1511340343    10502
# 1454528305     8114
# 1523381808     3931
# 1301832471     2877
# 1459953544     2680
#               ...
# 4212483577        1
# 1514504675        1
# 1522332242        1
# 1519120363        1
# 1448972460        1
# Name: count, Length: 149176, dtype: int64
# -------
#
# tesinting coff_timestamp
# coff_timestamp
# 1386525139    2512
# 1280658757    2330
# 1542344584    2307
# 1115757790     825
# 1442778241     770
#               ...
# 1408584451       1
# 1487929600       1
# 1464692082       1
# 1541882648       1
# 1544047232       1
# Name: count, Length: 52902, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training coff_machine
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting coff_machine
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training coff_characteristics
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting coff_characteristics
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_subsystem
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting optional_subsystem
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_dll_characteristics
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting optional_dll_characteristics
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_magic
# Series([], Name: count, dtype: int64)
# -------
#
# tesinting optional_magic
# Series([], Name: count, dtype: int64)
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_major_image_version
# optional_major_image_version
# 0       218154
# 6        31481
# 1        18382
# 10       18283
# 5        11651
#          ...
# 1337         1
# 1606         1
# 4431         1
# 83           1
# 1603         1
# Name: count, Length: 249, dtype: int64
# -------
#
# tesinting optional_major_image_version
# optional_major_image_version
# 0       83686
# 6       10408
# 1        5087
# 5        4315
# 10       3711
#         ...
# 2012        1
# 1997        1
# 250         1
# 38          1
# 72          1
# Name: count, Length: 100, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_minor_image_version
# optional_minor_image_version
# 0        282761
# 1         12224
# 2          3111
# 3          2341
# 8          1086
#           ...
# 15003         1
# 200           1
# 801           1
# 729           1
# 421           1
# Name: count, Length: 309, dtype: int64
# -------
#
# tesinting optional_minor_image_version
# optional_minor_image_version
# 0       101758
# 1         5263
# 2          886
# 3          475
# 5          220
#          ...
# 123          1
# 4065         1
# 964          1
# 2123         1
# 59           1
# Name: count, Length: 149, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_major_linker_version
# optional_major_linker_version
# 14     72356
# 6      69890
# 2      38481
# 9      33756
# 10     23620
#        ...
# 130        1
# 186        1
# 224        1
# 204        1
# 95         1
# Name: count, Length: 67, dtype: int64
# -------
#
# tesinting optional_major_linker_version
# optional_major_linker_version
# 6      29725
# 14     17732
# 10     11869
# 9      10629
# 2      10257
# 12      7659
# 8       7406
# 7       5636
# 11      4551
# 5       2865
# 3        593
# 4        463
# 16       192
# 13       191
# 83       153
# 1         74
# 0         48
# 18        44
# 113       30
# 115       22
# 17        18
# 15        16
# 255       12
# 103       12
# 27        11
# 117       11
# 105       11
# 118        8
# 73         6
# 48         5
# 99         5
# 242        4
# 24         2
# 50         2
# 19         2
# 154        2
# 37         2
# 53         1
# 43         1
# 21         1
# 56         1
# 222        1
# 47         1
# 95         1
# 33         1
# 84         1
# 23         1
# 135        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_minor_linker_version
# optional_minor_linker_version
# 0      208922
# 25      21675
# 11      17664
# 10      17556
# 12      10820
#         ...
# 73          1
# 150         1
# 250         1
# 200         1
# 57          1
# Name: count, Length: 77, dtype: int64
# -------
#
# tesinting optional_minor_linker_version
# optional_minor_linker_version
# 0      82351
# 10      6410
# 25      4134
# 15      4091
# 50      3630
#        ...
# 69         1
# 64         1
# 32         1
# 90         1
# 107        1
# Name: count, Length: 69, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_major_operating_system_version
# optional_major_operating_system_version
# 5        141067
# 4        113200
# 6         34771
# 10        17148
# 1          2010
# 0           126
# 3            84
# 7            19
# 8            10
# 56653         8
# 65535         4
# 1011          1
# 2069          1
# 9596          1
# 9611          1
# 6581          1
# 13            1
# 1593          1
# 501           1
# 17            1
# 14            1
# 1024          1
# Name: count, dtype: int64
# -------
#
# tesinting optional_major_operating_system_version
# optional_major_operating_system_version
# 4        48213
# 5        43164
# 6        14486
# 10        3344
# 1         1005
# 3           32
# 0           27
# 65535        2
# 2            1
# 14           1
# 32           1
# 13           1
# 8            1
# 10834        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_minor_operating_system_version
# optional_minor_operating_system_version
# 0        218087
# 1         79706
# 2          8666
# 3          1404
# 10          549
# 51           16
# 18327         8
# 4             5
# 20            4
# 11            3
# 7             1
# 6             1
# 256           1
# 1114          1
# 1598          1
# 191           1
# 1512          1
# 1292          1
# 32769         1
# 4353          1
# Name: count, dtype: int64
# -------
#
# tesinting optional_minor_operating_system_version
# optional_minor_operating_system_version
# 0     81759
# 1     24445
# 2      2144
# 10     1566
# 3       316
# 51       31
# 4         8
# 11        4
# 6         3
# 20        1
# 7         1
# 32        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_major_subsystem_version
# optional_major_subsystem_version
# 5      142819
# 4      120519
# 6       34693
# 10       9875
# 3         262
# 1         224
# 0          22
# 7          17
# 2          16
# 8           9
# 19          1
# 501         1
# Name: count, dtype: int64
# -------
#
# tesinting optional_major_subsystem_version
# optional_major_subsystem_version
# 4     52107
# 5     41666
# 6     14472
# 10     1912
# 3        82
# 1        29
# 0        10
# 8         1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_minor_subsystem_version
# optional_minor_subsystem_version
# 0        214112
# 1         78374
# 2         13724
# 10         1638
# 3           545
# 20           30
# 51           16
# 11            8
# 5             3
# 4             2
# 90            1
# 65280         1
# 50            1
# 144           1
# 257           1
# 12            1
# Name: count, dtype: int64
# -------
#
# tesinting optional_minor_subsystem_version
# optional_minor_subsystem_version
# 0      82657
# 1      24898
# 2       2412
# 10       142
# 3        134
# 50        27
# 51         5
# 20         3
# 257        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_sizeof_code
# optional_sizeof_code
# 262144      10732
# 169984       8159
# 8704         5200
# 761856       3980
# 4096         3709
#             ...
# 5515776         1
# 5664768         1
# 20375552        1
# 16170496        1
# 5459968         1
# Name: count, Length: 11130, dtype: int64
# -------
#
# tesinting optional_sizeof_code
# optional_sizeof_code
# 28672      3769
# 49152      3457
# 12800      2412
# 361472     2319
# 57344      2239
#            ...
# 8941568       1
# 1516544       1
# 5128192       1
# 1520128       1
# 1375232       1
# Name: count, Length: 5955, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_sizeof_headers
# optional_sizeof_headers
# 1024       231343
# 4096        70813
# 1536         4769
# 512           715
# 2048          239
#             ...
# 752             1
# 3584000         1
# 7090176         1
# 5873664         1
# 1184            1
# Name: count, Length: 107, dtype: int64
# -------
#
# tesinting optional_sizeof_headers
# optional_sizeof_headers
# 1024       73312
# 4096       34191
# 1536        2148
# 512          350
# 2048         118
# 8192          34
# 1152          18
# 704           11
# 768           10
# 3584           9
# 896            8
# 12288          8
# 65536          7
# 736            7
# 1280           4
# 6144           4
# 213504         3
# 36864          3
# 203264         2
# 832            2
# 90112          2
# 1016           2
# 672            2
# 1144           2
# 126976         1
# 49152          1
# 1552           1
# 1120           1
# 40960          1
# 1032           1
# 114688         1
# 1093632        1
# 267264         1
# 1748992        1
# 1408           1
# 1630208        1
# 800            1
# 143360         1
# 16384          1
# 1112           1
# 2560           1
# 274944         1
# 576            1
# 720            1
# 3640           1
# 680            1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------
#
# training optional_sizeof_heap_commit
# optional_sizeof_heap_commit
# 4096       306370
# 0             883
# 8192          575
# 4352          382
# 192000         35
#             ...
# 1187840         1
# 1069056         1
# 1306624         1
# 1105920         1
# 4186            1
# Name: count, Length: 81, dtype: int64
# -------
#
# tesinting optional_sizeof_heap_commit
# optional_sizeof_heap_commit
# 4096        108803
# 4352          1117
# 8192           176
# 0              157
# 16777216         5
# 65536            4
# 32768            2
# 1380352          2
# 16384            2
# 128000           2
# 1024             1
# 11776            1
# 393216           1
# 8388608          1
# 36864            1
# 2097152          1
# 1048576          1
# 12288            1
# 256              1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Removing null columns from dataframes

# %%
df_training.dropna(how='all', axis=1, inplace=True)
df_testing.dropna(how='all', axis=1, inplace=True)

# %%
df_training.columns,df_testing.columns
# Out:
# (Index(['label', '.text_size', '.text_entropy', '.text_vsize', '.data_size',
#         '.data_entropy', '.data_vsize', '.rsrc_size', '.rsrc_entropy',
#         '.rsrc_vsize', 'machine', 'subsystem', 'general_size', 'general_vsize',
#         'general_has_debug', 'general_exports', 'general_imports',
#         'general_has_relocations', 'general_has_resources',
#         'general_has_signature', 'general_has_tls', 'general_symbols',
#         'strings_numstrings', 'strings_avlength', 'strings_printables',
#         'strings_entropy', 'strings_paths', 'strings_urls', 'strings_registry',
#         'strings_MZ', 'coff_timestamp', 'optional_major_image_version',
#         'optional_minor_image_version', 'optional_major_linker_version',
#         'optional_minor_linker_version',
#         'optional_major_operating_system_version',
#         'optional_minor_operating_system_version',
#         'optional_major_subsystem_version', 'optional_minor_subsystem_version',
#         'optional_sizeof_code', 'optional_sizeof_headers',
#         'optional_sizeof_heap_commit'],
#        dtype='object'),
#  Index(['label', '.text_size', '.text_entropy', '.text_vsize', '.data_size',
#         '.data_entropy', '.data_vsize', '.rsrc_size', '.rsrc_entropy',
#         '.rsrc_vsize', 'machine', 'subsystem', 'general_size', 'general_vsize',
#         'general_has_debug', 'general_exports', 'general_imports',
#         'general_has_relocations', 'general_has_resources',
#         'general_has_signature', 'general_has_tls', 'general_symbols',
#         'strings_numstrings', 'strings_avlength', 'strings_printables',
#         'strings_entropy', 'strings_paths', 'strings_urls', 'strings_registry',
#         'strings_MZ', 'coff_timestamp', 'optional_major_image_version',
#         'optional_minor_image_version', 'optional_major_linker_version',
#         'optional_minor_linker_version',
#         'optional_major_operating_system_version',
#         'optional_minor_operating_system_version',
#         'optional_major_subsystem_version', 'optional_minor_subsystem_version',
#         'optional_sizeof_code', 'optional_sizeof_headers',
#         'optional_sizeof_heap_commit'],
#        dtype='object'))

# %% [markdown]
# ## Encoding non integer columns

# %%
df_training['machine'].unique(),df_testing['machine'].unique()
#create a tuple of all the machine types in training and testing
machine_types = tuple(set(df_training['machine'].unique()).union(set(df_testing['machine'].unique())))
machine_types
#similar for subsystem
subsystem_types = tuple(set(df_training['subsystem'].unique()).union(set(df_testing['subsystem'].unique())))
subsystem_types
# Out:
# ('EFI_BOOT_SERVICE_DRIVER',
#  'WINDOWS_BOOT_APPLICATION',
#  'POSIX_CUI',
#  'NATIVE',
#  'EFI_APPLICATION',
#  'WINDOWS_CUI',
#  'UNKNOWN',
#  'WINDOWS_CE_GUI',
#  'WINDOWS_GUI')

# %% [markdown]
# ### Label Encoding

# %%
#replace the machine types with numbers using label encoder function
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(machine_types)
df_training['machine'] = le.transform(df_training['machine'])
df_testing['machine'] = le.transform(df_testing['machine'])
le.fit(subsystem_types)
df_training['subsystem'] = le.transform(df_training['subsystem'])
df_testing['subsystem'] = le.transform(df_testing['subsystem'])

# %%
df_training['subsystem'].unique()
# Out:
# array([8, 2, 7, 6, 5, 3, 4, 0, 1])

# %% [markdown]
# ### One hot encoding

# %%
columns_to_encode = ['machine', 'subsystem']

df_training = pd.get_dummies(df_training, columns=columns_to_encode)
df_testing = pd.get_dummies(df_testing, columns=columns_to_encode)

# %%
print("In training diff",df_training.columns.difference(df_testing.columns))
print("In testing diff",df_testing.columns.difference(df_training.columns))

# %% [markdown]
# ## Adding the columns

# %%
for column in df_training.columns.difference(df_testing.columns):
    df_testing[column] = 0  
    
for column in df_testing.columns.difference(df_training.columns):
  df_training[column]= 0
  
df_testing = df_testing[df_training.columns]

# %%
df_training.columns

# %% [markdown]
# ## Direct load

# %%
#save the dataframes to csv files
df_training.to_csv('../filtered-data/original/training_label.csv', index=False)
df_testing.to_csv('../filtered-data/original/testing_label.csv', index=False)
df_testing.to_csv('ember_testing.csv', index=False)

# %%
#load from csv to df
df_training = pd.read_csv('../filtered-data/original/training.csv')
df_testing = pd.read_csv('../filtered-data/original/testing.csv')

# %%
df_training['label'].value_counts()
# Out:
# label
# 0    157725
# 1    150733
# Name: count, dtype: int64

# %% [markdown]
# ## Data pruning

# %%
exclude_columns= [
"machine", "subsystem", "label"
]
threshold = 0.98
for column in df_training.columns:

    if df_training[column].max()>10*df_training[column].median() and df_training[column].max()>10 and all([ not column.startswith(x) for x in exclude_columns]) :
        df_training[column] = np.where(df_training[column]<df_training[column].quantile(threshold), df_training[column], df_training[column].quantile(threshold))

# %%
df_training.describe()
# Out:
#                label    .text_size  .text_entropy   .text_vsize  \
# count  308458.000000  3.084580e+05  308458.000000  3.084580e+05
# mean        0.488666  4.381067e+05       6.293713  4.486803e+05
# std         0.499872  8.070612e+05       0.941002  8.204198e+05
# min         0.000000  0.000000e+00      -0.000000  0.000000e+00
# 25%         0.000000  3.276800e+04       6.226783  3.390800e+04
# 50%         0.000000  1.377280e+05       6.496109  1.405150e+05
# 75%         1.000000  3.809280e+05       6.635043  4.009725e+05
# max         1.000000  4.005376e+06       7.999991  4.016800e+06
#
#           .data_size  .data_entropy   .data_vsize    .rsrc_size  \
# count  308458.000000  308458.000000  3.084580e+05  3.084580e+05
# mean    44537.020392       3.276747  1.739107e+05  3.268540e+05
# std    140283.803270       1.972248  5.818919e+05  8.004498e+05
# min         0.000000      -0.000000  0.000000e+00  0.000000e+00
# 25%      2048.000000       1.967524  4.784000e+03  4.096000e+03
# 50%      5120.000000       3.589640  1.509400e+04  2.457600e+04
# 75%     14848.000000       4.638543  8.708800e+04  1.925120e+05
# max    806912.000000       8.000000  3.735964e+06  4.276521e+06
#
#        .rsrc_entropy   .rsrc_vsize  ...  optional_minor_image_version  \
# count  308458.000000  3.084580e+05  ...                 308458.000000
# mean        4.939024  3.271366e+05  ...                      0.209481
# std         1.851902  8.001068e+05  ...                      0.852369
# min        -0.000000  0.000000e+00  ...                      0.000000
# 25%         3.769816  2.704000e+03  ...                      0.000000
# 50%         4.849330  2.560000e+04  ...                      0.000000
# 75%         6.051792  1.919160e+05  ...                      0.000000
# max         7.999997  4.269253e+06  ...                      5.000000
#
#        optional_major_linker_version  optional_minor_linker_version  \
# count                  308458.000000                  308458.000000
# mean                        8.728378                       6.425098
# std                         3.987054                      11.859093
# min                         0.000000                       0.000000
# 25%                         6.000000                       0.000000
# 50%                         9.000000                       0.000000
# 75%                        12.000000                      11.000000
# max                        14.000000                      50.000000
#
#        optional_major_operating_system_version  \
# count                            308458.000000
# mean                                  4.995643
# std                                   1.409780
# min                                   0.000000
# 25%                                   4.000000
# 50%                                   5.000000
# 75%                                   5.000000
# max                                  10.000000
#
#        optional_minor_operating_system_version  \
# count                            308458.000000
# mean                                  0.327552
# std                                   0.537971
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   1.000000
# max                                   2.000000
#
#        optional_major_subsystem_version  optional_minor_subsystem_version  \
# count                     308458.000000                     308458.000000
# mean                           4.876943                          0.357644
# std                            1.142940                          0.577318
# min                            0.000000                          0.000000
# 25%                            4.000000                          0.000000
# 50%                            5.000000                          0.000000
# 75%                            5.000000                          1.000000
# max                           10.000000                          2.000000
#
#        optional_sizeof_code  optional_sizeof_headers  \
# count          3.084580e+05            308458.000000
# mean           4.550367e+05              1738.603612
# std            8.296079e+05              1291.241446
# min            0.000000e+00                 0.000000
# 25%            3.532800e+04              1024.000000
# 50%            1.433600e+05              1024.000000
# 75%            4.085760e+05              1024.000000
# max            4.058624e+06              4096.000000
#
#        optional_sizeof_heap_commit
# count                308458.000000
# mean                   4084.226702
# std                     219.247506
# min                       0.000000
# 25%                    4096.000000
# 50%                    4096.000000
# 75%                    4096.000000
# max                    4096.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ## Log Modification

# %%
x = []
for column in df_training.columns:
  if(df_training[column].nunique() >50):
    print(df_training[column].value_counts())
# print(type(x))
# print(sorted(x))
# Out:
# .text_size
# 262144.0     10685
# 169984.0      8156
# 4005376.0     6323
# 6656.0        4887
# 761856.0      3974
#              ...
# 1885184.0        1
# 3313664.0        1
# 142010.0         1
# 3874816.0        1
# 3092992.0        1
# Name: count, Length: 6968, dtype: int64
# .text_entropy
#  6.640590    10482
#  6.719869     8112
#  6.610926     3930
#  6.191553     3534
# -0.000000     2996
#              ...
#  6.333208        1
#  6.497638        1
#  6.068958        1
#  6.284015        1
#  6.447386        1
# Name: count, Length: 160207, dtype: int64
# .text_vsize
# 261943.0     10503
# 169476.0      8114
# 4016800.0     6208
# 761122.0      3936
# 6552.0        3540
#              ...
# 8838.0           1
# 548500.0         1
# 154100.0         1
# 201684.0         1
# 34613.0          1
# Name: count, Length: 101778, dtype: int64
# .data_size
# 4096.0      36242
# 512.0       31231
# 1024.0      18987
# 7680.0      14674
# 3584.0      13866
#             ...
# 3224.0          1
# 17760.0         1
# 148608.0        1
# 729600.0        1
# 23708.0         1
# Name: count, Length: 1884, dtype: int64
# .data_entropy
# -0.000000    33111
#  4.082739    10474
#  3.589640     8112
#  4.957800     3935
#  4.516155     2875
#              ...
#  4.133104        1
#  1.640984        1
#  3.957756        1
#  6.637066        1
#  3.481159        1
# Name: count, Length: 118716, dtype: int64
# .data_vsize
# 11404.0      10537
# 136712.0      8116
# 3735964.0     6184
# 3208.0        4008
# 283818.0      3936
#              ...
# 34636.0          1
# 58884.0          1
# 792768.0         1
# 1753859.0        1
# 39233.0          1
# Name: count, Length: 35408, dtype: int64
# .rsrc_size
# 1536.0       20772
# 4096.0       20231
# 1024.0       17329
# 512.0        10592
# 749568.0     10523
#              ...
# 36370.0          1
# 287334.0         1
# 1649664.0        1
# 2230272.0        1
# 1468160.0        1
# Name: count, Length: 6508, dtype: int64
# .rsrc_entropy
# -0.000000    10559
#  5.391061    10435
#  4.706937     8072
#  3.769816     3935
#  5.067445     3534
#              ...
#  3.161820        1
#  6.749028        1
#  5.716910        1
#  4.910814        1
#  6.977566        1
# Name: count, Length: 172726, dtype: int64
# .rsrc_vsize
# 749176.00     10502
# 18048.00       8222
# 4269253.44     6170
# 480.00         4673
# 700.00         4398
#               ...
# 821368.00         1
# 541820.00         1
# 455488.00         1
# 115640.00         1
# 192484.00         1
# Name: count, Length: 48613, dtype: int64
# general_size
# 14752338.72    6170
# 139264.00      2254
# 595496.00      2239
# 5267459.00     1976
# 1130344.00     1295
#                ...
# 2920705.00        1
# 5319392.00        1
# 1139437.00        1
# 1973936.00        1
# 298685.00         1
# Name: count, Length: 112148, dtype: int64
# general_vsize
# 1134592.0     10652
# 360448.0       8763
# 14295040.0     6174
# 28672.0        6037
# 32768.0        4345
#               ...
# 12320.0           1
# 10907648.0        1
# 11964416.0        1
# 13029376.0        1
# 13074432.0        1
# Name: count, Length: 3631, dtype: int64
# general_exports
# 0.0      232491
# 1.0       14250
# 3.0       11490
# 2.0        8178
# 4.0        7453
#           ...
# 308.0         3
# 252.0         3
# 315.0         2
# 286.0         2
# 299.0         1
# Name: count, Length: 323, dtype: int64
# general_imports
# 247.0    13106
# 0.0      12818
# 137.0     8635
# 155.0     8060
# 660.0     6177
#          ...
# 626.0       19
# 627.0       19
# 653.0       16
# 642.0       14
# 657.0       14
# Name: count, Length: 661, dtype: int64
# strings_numstrings
# 3312.00     10451
# 72555.66     6170
# 3753.00      3959
# 3348.00      2453
# 475.00       1924
#             ...
# 32759.00        1
# 24369.00        1
# 12170.00        1
# 13777.00        1
# 22649.00        1
# Name: count, Length: 32134, dtype: int64
# strings_avlength
# 41.297281    6170
# 14.227368    1843
# 11.258747    1573
# 14.029948     747
# 24.930857     726
#              ...
# 5.721847        1
# 7.915875        1
# 9.472993        1
# 14.526761       1
# 7.624108        1
# Name: count, Length: 233093, dtype: int64
# strings_printables
# 919413.0    6171
# 6758.0      1848
# 29284.0     1575
# 10775.0      760
# 82571.0      726
#             ...
# 220415.0       1
# 406469.0       1
# 677465.0       1
# 169221.0       1
# 28152.0        1
# Name: count, Length: 109517, dtype: int64
# strings_entropy
# 5.263887    1843
# 5.681257     747
# 5.178692     621
# 4.949852     595
# 5.220300     467
#             ...
# 5.595420       1
# 6.539338       1
# 5.754809       1
# 5.834127       1
# 6.051849       1
# Name: count, Length: 277026, dtype: int64
# strings_urls
# 0.0      148700
# 1.0       34168
# 39.0      11292
# 20.0      10324
# 2.0        8271
#           ...
# 101.0        22
# 103.0        22
# 113.0        22
# 126.0        18
# 117.0        17
# Name: count, Length: 130, dtype: int64
# strings_MZ
# 1.0      48103
# 2.0      40421
# 3.0      37722
# 4.0      28203
# 8.0      21709
#          ...
# 141.0       43
# 142.0       42
# 146.0       40
# 143.0       40
# 144.0       38
# Name: count, Length: 148, dtype: int64
# coff_timestamp
# 1511340343    10502
# 1454528305     8114
# 1523381808     3931
# 1301832471     2877
# 1459953544     2680
#               ...
# 4212483577        1
# 1514504675        1
# 1522332242        1
# 1519120363        1
# 1448972460        1
# Name: count, Length: 149176, dtype: int64
# optional_sizeof_code
# 262144.0     10732
# 169984.0      8159
# 4058624.0     6210
# 8704.0        5200
# 761856.0      3980
#              ...
# 3260928.0        1
# 2276864.0        1
# 2948096.0        1
# 1738240.0        1
# 28196.0          1
# Name: count, Length: 7099, dtype: int64

# %%
for column in df_training.columns:
    if df_training[column].nunique()>50 and df_training[column].max() > 10*df_training[column].median():
      print(column)
      df_training[column] = np.log(df_training[column]+1)
      df_testing[column] = np.log(df_testing[column]+1)
# Out:
# .text_size
# .text_vsize
# .data_size
# .data_vsize
# .rsrc_size
# .rsrc_vsize
# general_size
# general_vsize
# general_exports
# strings_numstrings
# strings_printables
# strings_urls
# strings_MZ
# optional_sizeof_code

# %%
df_training.describe()
# Out:
#                label     .text_size  .text_entropy    .text_vsize  \
# count  308458.000000  308458.000000  308458.000000  308458.000000
# mean        0.488666      11.626810       6.293713      11.703576
# std         0.499872       2.019628       0.941002       1.806895
# min         0.000000       0.000000      -0.000000       0.000000
# 25%         0.000000      10.397238       6.226783      10.431436
# 50%         0.000000      11.833043       6.496109      11.853077
# 75%         1.000000      12.850368       6.635043      12.901651
# max         1.000000      15.203148       7.999991      15.205996
#
#           .data_size  .data_entropy    .data_vsize     .rsrc_size  \
# count  308458.000000  308458.000000  308458.000000  308458.000000
# mean        8.575505       3.276747       9.802944      10.301058
# std         2.257271       1.972248       2.190746       2.427110
# min         0.000000      -0.000000       0.000000       0.000000
# 25%         7.625107       1.967524       8.473241       8.318010
# 50%         8.541105       3.589640       9.622119      10.109566
# 75%         9.605688       4.638543      11.374686      12.167919
# max        13.600971       8.000000      15.133517      15.268651
#
#        .rsrc_entropy    .rsrc_vsize  ...  optional_minor_image_version  \
# count  308458.000000  308458.000000  ...                 308458.000000
# mean        4.939024      10.201646  ...                      0.209481
# std         1.851902       2.554412  ...                      0.852369
# min        -0.000000       0.000000  ...                      0.000000
# 25%         3.769816       7.902857  ...                      0.000000
# 50%         4.849330      10.150387  ...                      0.000000
# 75%         6.051792      12.164818  ...                      0.000000
# max         7.999997      15.266950  ...                      5.000000
#
#        optional_major_linker_version  optional_minor_linker_version  \
# count                  308458.000000                  308458.000000
# mean                        8.728378                       6.425098
# std                         3.987054                      11.859093
# min                         0.000000                       0.000000
# 25%                         6.000000                       0.000000
# 50%                         9.000000                       0.000000
# 75%                        12.000000                      11.000000
# max                        14.000000                      50.000000
#
#        optional_major_operating_system_version  \
# count                            308458.000000
# mean                                  4.995643
# std                                   1.409780
# min                                   0.000000
# 25%                                   4.000000
# 50%                                   5.000000
# 75%                                   5.000000
# max                                  10.000000
#
#        optional_minor_operating_system_version  \
# count                            308458.000000
# mean                                  0.327552
# std                                   0.537971
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   1.000000
# max                                   2.000000
#
#        optional_major_subsystem_version  optional_minor_subsystem_version  \
# count                     308458.000000                     308458.000000
# mean                           4.876943                          0.357644
# std                            1.142940                          0.577318
# min                            0.000000                          0.000000
# 25%                            4.000000                          0.000000
# 50%                            5.000000                          0.000000
# 75%                            5.000000                          1.000000
# max                           10.000000                          2.000000
#
#        optional_sizeof_code  optional_sizeof_headers  \
# count         308458.000000            308458.000000
# mean              11.725224              1738.603612
# std                1.851200              1291.241446
# min                0.000000                 0.000000
# 25%               10.472459              1024.000000
# 50%               11.873121              1024.000000
# 75%               12.920436              1024.000000
# max               15.216355              4096.000000
#
#        optional_sizeof_heap_commit
# count                308458.000000
# mean                   4084.226702
# std                     219.247506
# min                       0.000000
# 25%                    4096.000000
# 50%                    4096.000000
# 75%                    4096.000000
# max                    4096.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# ## Standardization

# %%
# Columns to exclude from standardization
def standardize(df,df_train_fit):
    scaler = StandardScaler()
    exclude_columns= [
    "machine", "subsystem", "label"
    ]

    df_standardized = df.copy()

    for column in df.columns:
        if all([ not column.startswith(x) for x in exclude_columns]):
            # Standardize the column
            scaler = scaler.fit(df_train_fit[column].values.reshape(-1, 1))
            df_standardized[column] = scaler.transform(df[column].values.reshape(-1, 1))

    return df_standardized

df_training_standardized = standardize(df_training,df_training)
df_testing_standardized = standardize(df_testing,df_training)

# %%
df_training_standardized.describe()
# Out:
#                label    .text_size  .text_entropy   .text_vsize    .data_size  \
# count  308458.000000  3.084580e+05   3.084580e+05  3.084580e+05  3.084580e+05
# mean        0.488666 -6.265606e-18  -1.261068e-15  1.130758e-15 -1.976430e-16
# std         0.499872  1.000002e+00   1.000002e+00  1.000002e+00  1.000002e+00
# min         0.000000 -5.756915e+00  -6.688324e+00 -6.477185e+00 -3.799064e+00
# 25%         0.000000 -6.088119e-01  -7.112721e-02 -7.040488e-01 -4.210391e-01
# 50%         0.000000  1.021147e-01   2.150856e-01  8.273895e-02 -1.523971e-02
# 75%         1.000000  6.058344e-01   3.627305e-01  6.630579e-01  4.563848e-01
# max         1.000000  1.770793e+00   1.813260e+00  1.938367e+00  2.226349e+00
#
#        .data_entropy   .data_vsize    .rsrc_size  .rsrc_entropy   .rsrc_vsize  \
# count   3.084580e+05  3.084580e+05  3.084580e+05   3.084580e+05  3.084580e+05
# mean    6.449888e-17 -8.373798e-16 -1.285923e-15   2.211390e-18  3.490311e-16
# std     1.000002e+00  1.000002e+00  1.000002e+00   1.000002e+00  1.000002e+00
# min    -1.661430e+00 -4.474713e+00 -4.244173e+00  -2.667005e+00 -3.993741e+00
# 25%    -6.638235e-01 -6.069646e-01 -8.170421e-01  -6.313558e-01 -8.999301e-01
# 50%     1.586481e-01 -8.254071e-02 -7.889720e-02  -4.843349e-02 -2.006706e-02
# 75%     6.904802e-01  7.174470e-01  7.691715e-01   6.008797e-01  7.685428e-01
# max     2.394861e+00  2.433227e+00  2.046714e+00   1.652883e+00  1.982966e+00
#
#        ...  optional_minor_image_version  optional_major_linker_version  \
# count  ...                  3.084580e+05                   3.084580e+05
# mean   ...                 -2.119249e-17                  -1.708299e-16
# std    ...                  1.000002e+00                   1.000002e+00
# min    ...                 -2.457633e-01                  -2.189184e+00
# 25%    ...                 -2.457633e-01                  -6.843104e-01
# 50%    ...                 -2.457633e-01                   6.812612e-02
# 75%    ...                 -2.457633e-01                   8.205627e-01
# max    ...                  5.620250e+00                   1.322187e+00
#
#        optional_minor_linker_version  optional_major_operating_system_version  \
# count                   3.084580e+05                             3.084580e+05
# mean                    3.317085e-17                             9.619548e-17
# std                     1.000002e+00                             1.000002e+00
# min                    -5.417875e-01                            -3.543567e+00
# 25%                    -5.417875e-01                            -7.062409e-01
# 50%                    -5.417875e-01                             3.090669e-03
# 75%                     3.857723e-01                             3.090669e-03
# max                     3.674393e+00                             3.549749e+00
#
#        optional_minor_operating_system_version  \
# count                             3.084580e+05
# mean                             -2.672097e-17
# std                               1.000002e+00
# min                              -6.088661e-01
# 25%                              -6.088661e-01
# 50%                              -6.088661e-01
# 75%                               1.249973e+00
# max                               3.108811e+00
#
#        optional_major_subsystem_version  optional_minor_subsystem_version  \
# count                      3.084580e+05                      3.084580e+05
# mean                      -3.499525e-16                      8.329570e-17
# std                        1.000002e+00                      1.000002e+00
# min                       -4.267023e+00                     -6.194924e-01
# 25%                       -7.672705e-01                     -6.194924e-01
# 50%                        1.076675e-01                     -6.194924e-01
# 75%                        1.076675e-01                      1.112658e+00
# max                        4.482358e+00                      2.844809e+00
#
#        optional_sizeof_code  optional_sizeof_headers  \
# count          3.084580e+05             3.084580e+05
# mean          -1.901796e-15            -6.044467e-17
# std            1.000002e+00             1.000002e+00
# min           -6.333862e+00            -1.346461e+00
# 25%           -6.767325e-01            -5.534246e-01
# 50%            7.989258e-02            -5.534246e-01
# 75%            6.456426e-01            -5.534246e-01
# max            1.885878e+00             1.825685e+00
#
#        optional_sizeof_heap_commit
# count                 3.084580e+05
# mean                 -5.706769e-16
# std                   1.000002e+00
# min                  -1.862841e+01
# 25%                   5.369875e-02
# 50%                   5.369875e-02
# 75%                   5.369875e-02
# max                   5.369875e-02
#
# [8 rows x 42 columns]

# %% [markdown]
# ## Saving to csv

# %%
df_training_standardized.to_csv('../filtered-data/standardizedv3/training.csv',index= False)
df_testing_standardized.to_csv('../filtered-data/standardizedv3/testing.csv',index= False)

# %%
# df_training.to_csv('../filtered-data/original/training.csv',index= False)
# df_testing.to_csv('../filtered-data/original/testing.csv',index= False)
df_training_standardized.to_csv('../filtered-data/standardizedv2/training.csv',index= False)
df_testing_standardized.to_csv('../filtered-data/standardizedv2/testing.csv',index= False)

# %%
df_training_standardized['label'].value_counts()
# Out:
# label
# 0    157725
# 1    150733
# Name: count, dtype: int64

# %%
df_testing_standardized['label'].value_counts()
# Out:
# label
# 0    57489
# 1    52790
# Name: count, dtype: int64

# %%
# for column_name in df_training.columns:
#     print(column_name)
print(df_training.columns.difference(df_testing.columns))
print(df_testing.columns.difference(df_training.columns))

print(df_training_standardized.columns.difference(df_testing_standardized.columns))
print(df_testing_standardized.columns.difference(df_training_standardized.columns))

# %% [markdown]
# # Column distributions

# %%
print("Training",df_training.var(),sep = "\n")

# %%
df_training.describe()

# %%
#plot normal distribution of features
def plot_normal_distribution(df):
    for column in df.columns:
        sns.distplot(df[column])
        plt.show()
        
plot_normal_distribution(df_training_standardized)
# Out:
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])
# /tmp/ipykernel_7656/3831127953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[column])

# %%
for column in df_training.columns:
    sns.boxplot(df_training[column])
    plt.title(f'Distribution of {column}')
    plt.show()

# %% [markdown]
# # Training and Testing Data Split

# %%
ember_data = "../../../dataset/ember2018"


ember.create_vectorized_features(ember_data)
ember.create_metadata(ember_data)
# Out:
# WARNING: EMBER feature version 2 were computed using lief version 0.9.0-
# WARNING:   lief version 0.14.0-16962f2f found instead. There may be slight inconsistencies
# WARNING:   in the feature calculations.
# Vectorizing training set
#   0%|          | 0/800000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/__init__.py", line 44, in vectorize_unpack
#     return vectorize(*args)
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/__init__.py", line 31, in vectorize
#     feature_vector = extractor.process_raw_features(raw_features)
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/features.py", line 552, in process_raw_features
#     feature_vectors = [fe.process_raw_features(raw_obj[fe.name]) for fe in self.features]
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/features.py", line 552, in <listcomp>
#     feature_vectors = [fe.process_raw_features(raw_obj[fe.name]) for fe in self.features]
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/features.py", line 192, in process_raw_features
#     entry_name_hashed = FeatureHasher(50, input_type="string").transform([raw_obj['entry']]).toarray()[0]
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#   File "/home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/feature_extraction/_hash.py", line 169, in transform
#     raise ValueError(
# ValueError: Samples can not be a single string. The input must be an iterable over iterables of strings.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 ember_data = "../../../dataset/ember2018"
# ----> 4 ember.create_vectorized_features(ember_data)
#       5 ember.create_metadata(ember_data)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/__init__.py:75, in create_vectorized_features(data_dir, feature_version)
#      73 raw_feature_paths = [os.path.join(data_dir, "train_features_{}.jsonl".format(i)) for i in range(6)]
#      74 nrows = sum([1 for fp in raw_feature_paths for line in open(fp)])
# ---> 75 vectorize_subset(X_path, y_path, raw_feature_paths, extractor, nrows)
#      77 print("Vectorizing test set")
#      78 X_path = os.path.join(data_dir, "X_test.dat")
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/ember-0.1.0-py3.9.egg/ember/__init__.py:60, in vectorize_subset(X_path, y_path, raw_feature_paths, extractor, nrows)
#      57 pool = multiprocessing.Pool()
#      58 argument_iterator = ((irow, raw_features_string, X_path, y_path, extractor, nrows)
#      59                      for irow, raw_features_string in enumerate(raw_feature_iterator(raw_feature_paths)))
# ---> 60 for _ in tqdm.tqdm(pool.imap_unordered(vectorize_unpack, argument_iterator), total=nrows):
#      61     pass
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1179 time = self._time
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#    1184         # Update and possibly print the progressbar.
#    1185         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/miniconda3/envs/tf/lib/python3.9/multiprocessing/pool.py:870, in IMapIterator.next(self, timeout)
#     868 if success:
#     869     return value
# --> 870 raise value
#
# ValueError: Samples can not be a single string. The input must be an iterable over iterables of strings.

# %%
datasetDirectory = '../../filtered-data/standardizedv3'

# X_train, X_test, y_train, y_test = data_loading.getTrainTestData(datasetDirectory,validation = False)
X_train, X_val, X_test, y_train, y_val, y_test = data_loading.getTrainTestData(datasetDirectory,validation = True)

# %%
print("In training diff",X_train.columns.difference(X_test.columns))
print("In testing diff",X_test.columns.difference(X_train.columns))
# Out:
# In training diff Index([], dtype='object')
# In testing diff Index([], dtype='object')

# %% [markdown]
# # PCA

# %%
max_variance_to_explain = 0.98

pca = PCA(max_variance_to_explain)
pca.fit(X_train)
pca_data = pca.transform(X_train)

# %%
X_train.shape
# Out:
# (246766, 60)

# %%
pca_data.shape
# Out:
# (246766, 32)

# %% [markdown]
# ## Graphs

# %% [markdown]
# ### Bar graph

# %%
per_var = np.round(pca.explained_variance_ratio_* 100, decimals=1)
per_var = [x for x in per_var if x >0.0]
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
plt.figure().set_figwidth(20)
 
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)

plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# ### Top columns

# %%
loading_scores = pd.Series(pca.components_[0], index=X_train.columns)
sorted_loading_scores = loading_scores.abs().sort_values(ascending=False)
 
columns_req = 20
 
top_columns = sorted_loading_scores[0:columns_req].index.values
print(top_columns)
print(loading_scores[top_columns])
# Out:
# ['general_size' 'strings_numstrings' 'strings_printables' 'general_vsize'
#  '.text_vsize' 'optional_sizeof_code' '.text_size' 'general_imports'
#  'strings_MZ' '.rsrc_vsize' '.rsrc_size' '.data_size' 'general_has_tls'
#  '.data_vsize' '.data_entropy' 'strings_urls' '.rsrc_entropy'
#  'general_has_signature' 'strings_entropy' 'general_has_relocations']
# general_size              -0.309546
# strings_numstrings        -0.304708
# strings_printables        -0.303223
# general_vsize             -0.286908
# .text_vsize               -0.266079
# optional_sizeof_code      -0.259980
# .text_size                -0.241698
# general_imports           -0.234729
# strings_MZ                -0.214870
# .rsrc_vsize               -0.211028
# .rsrc_size                -0.210926
# .data_size                -0.189090
# general_has_tls           -0.180491
# .data_vsize               -0.163761
# .data_entropy             -0.154249
# strings_urls              -0.152213
# .rsrc_entropy             -0.144902
# general_has_signature     -0.112240
# strings_entropy           -0.100167
# general_has_relocations   -0.097526
# dtype: float32

# %% [markdown]
# ## Transforming

# %%
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)
try:
  X_val = pca.transform(X_val)
except:
  pass

# %%
X_train.shape,X_test.shape,X_val.shape
# Out:
# ((246766, 32), (110279, 32), (61692, 32))

# %% [markdown]
# # Random Forest Classifier

# %%
rf = RandomForestClassifier(n_estimators=100, n_jobs=50, random_state=42, verbose=1, criterion='entropy',warm_start=True)

rf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=50)]: Using backend ThreadingBackend with 50 concurrent workers.
# [Parallel(n_jobs=50)]: Done 100 out of 100 | elapsed:    5.0s finished
# RandomForestClassifier(criterion='entropy', n_jobs=50, random_state=42,
#                        verbose=1, warm_start=True)

# %%
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(y_pred)
# Out:
# [Parallel(n_jobs=50)]: Using backend ThreadingBackend with 50 concurrent workers.
# Accuracy: 0.9357901323008007
# [0 1 0 ... 1 1 0]
# [Parallel(n_jobs=50)]: Done 100 out of 100 | elapsed:    0.3s finished

# %% [markdown]
# ## Graphs

# %% [markdown]
# ### Confusion matrix

# %%
# confusion matrix



def plot_confusion_matrix(y_true, y_pred, labels, title):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=True, fmt='g')
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
  
plot_confusion_matrix(y_test, y_pred, labels=[0, 1], title='Random Forest')

# %%
feature_importances = rf.feature_importances_
feature_importances = pd.DataFrame({'feature': X_train.columns, 'importance': feature_importances}).sort_values('importance', ascending = False)
# plot feature importances
plt.figure(figsize = (8, 6))
sns.barplot(x = 'importance', y = 'feature', data = feature_importances)
plt.title('Feature Importances')
plt.show()

# %%
# Create a function to plot learning curves
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# Assuming you have defined rf and your data (X_train, y_train)
title = "Learning Curves (Random Forest)"
plot_learning_curve(rf, title, X_train, y_train, cv=5, n_jobs=68)
plt.show()

# %% [markdown]
# # Base Model Class

# %% [markdown]
# ## Base class

# %%
class Model:
  
  def __init__(self):
    self.model = Sequential()
  
  def addInputLayer(self,input_dim):
    self.model.add(Input(shape=(input_dim,)))
  
  def __addLayer(self,perceptrons,activation,dropout,regularizer):
    if regularizer != 0:
      self.model.add(Dense(perceptrons,activation=activation,kernel_regularizer=regularizers.l2(regularizer)))
    else:
      self.model.add(Dense(perceptrons,activation=activation))
    
    if(dropout !=0):
      self.model.add(Dropout(dropout))

  
  def addLayers(self,layers, activation_functions,dropouts=[],regularizers=[]):
    while len(regularizers) < len(layers):
      regularizers.append(0)
    while len(activation_functions) < len(layers):
      activation_functions.append('sigmoid')
    
    while(len(dropouts)< len(layers)):
      dropouts.append(0)
    for (perceptrons,activation,dropout,regularizer) in zip(layers,activation_functions,dropouts,regularizers):
      self.__addLayer(perceptrons,activation,dropout,regularizer)
    
  def compile(self):
    self.model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'], weighted_metrics=[])
    
  def get_model(self):
    self.model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'], weighted_metrics=[])
    return self.model
  
  # def fit(self,X_train=X_train, y_train=y_train, epochs=100, batch_size=2048, validation_data=(X_val, y_val)):
  #   self.history = self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=validation_data, verbose=1)
    
  # def predict(self,X_test= X_test,y_test = y_test):
  #   y_pred = self.model.predict(X_test)
  #   y_pred_real = [int(round(x[0])) for x in y_pred]
  #   y_pred_real = np.array(y_pred_real)
  #   return y_pred_real
  
  def show(self):   
    print(self.model.summary())
    tf.keras.utils.plot_model(self.model, show_shapes=True,show_layer_names=False)

# %%
layers = [50,25,12,1]
activations = ['relu','relu','relu','sigmoid']
dropouts = [0.2,0.2,0.2]
regularizers_1 = [0.01,0.01]
model_1 = Model()
model_1.addInputLayer(X_train.shape[1])
model_1.addLayers(layers,activations,dropouts,regularizers_1)
model_1.compile()
model_1.fit()

# %%
y_pred = model_1.model.predict(X_test)

y_pred_real = [int(round(x[0])) for x in y_pred]
y_pred_real = np.array(y_pred_real)

accuracy_score(y_test, y_pred_real)

# %%
def plot_confusion_matrix(y_true, y_pred, labels, title):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=True, fmt='g')
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
  
plot_confusion_matrix(y_test, y_pred_real, labels=[0, 1], title='Confusion matrix')

# %%
#get training loss
def plot_loss_curves(history):
  train_loss = history.history['loss']
  #get validation loss
  val_loss = history.history['val_loss']
  #plot graph

  plt.plot(train_loss, label='Training Loss')
  plt.plot(val_loss, label='Validation Loss')
  plt.legend()
  plt.show()

# %% [markdown]
# # K Fold

# %% [markdown]
# ## fit

# %%
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)
models = []

layers = [100,100,100,1]
activations = ['relu','relu','relu','sigmoid']
dropouts = [0.2,0.2,0.2]
regularizers_1 = [0.01,0.01]
for i in range(10):
    model_1 = Model()
    model_1.addInputLayer(X_train.shape[1])
    model_1.addLayers(layers,activations,dropouts,regularizers_1)
    model_1.compile()
    models.append(model_1)
i = 0
for train_index, val_index in skf.split(X_train, y_train):
    
    x_train_fold, x_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
    models[i].fit(x_train_fold,y_train_fold,validation_data=(x_val_fold,y_val_fold))
    i+=1

# %%
list1 = [2, 2, 2, 3, 4]
list2 = [2, 2, 3, 4, 4]
list3 = [1, 2, 3, 4, 4]
list4 = [2, 2, 3, 4, 4]

# Create a NumPy array from the lists
lists_array = np.array([list1, list2, list3,list4])

# Use NumPy to find the mode (most frequent element) for each index
max_freq_elements = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=lists_array)

# max_freq_elements now contains the element with the maximum frequency for each index
print(max_freq_elements)

# %% [markdown]
# ## Graph

# %%
y_pred_list =[]
for i,model in enumerate(models):
  y_pred_list.append(model.predict(X_test,y_test))
  print(accuracy_score(y_test,y_pred_list[-1]))
  plot_confusion_matrix(y_test, y_pred_list[-1], labels=[0, 1], title='Confusion matrix_' +str(i))
  plot_loss_curves(model.history)

y_pred_final = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=y_pred_list)

print(accuracy_score(y_test,y_pred_final))

# %%
print(accuracy_score(y_test,y_pred_final))
plot_confusion_matrix(y_test, y_pred_final, labels=[0, 1], title='Confusion matrix K fold')

# %%
print(classification_report(y_test,y_pred_final))

# %% [markdown]
# # MODEL2 - Bagging

# %% [markdown]
# ## Model

# %%
layers = [64,8,4,1]
activations = ['relu','relu','relu','sigmoid']
dropouts = []
regularizers_1 = [0.01,0.01,0.01]
max_features = math.ceil(math.sqrt(X_train.shape[1]))+10


def get_model():
  model = Model()
  model.addInputLayer(max_features)
  model.addLayers(layers,activations,dropouts,regularizers_1)
  model.show()
  return model.get_model()

model= KerasClassifier(model=get_model, epochs=100, batch_size=512,random_state=42,verbose=1,validation_split=0.2)

bagg = BaggingClassifier(estimator=model,n_estimators=50,max_features = max_features,verbose =1,random_state=42,max_samples=4096,n_jobs=-1)

# %% [markdown]
# ## fit

# %%
bagg.fit(X_train,y_train)

# %% [markdown]
# ## predict

# %%
y_pred = bagg.predict(X_test)

# %% [markdown]
# ## Graph

# %%
def plot_confusion_matrix(y_true, y_pred, labels, title):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=True, fmt='g')
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
# accuracy
print(accuracy_score(y_test, y_pred.round()))

# confusion matrix
plot_confusion_matrix(y_test, y_pred.round(), labels=[0, 1], title='Confusion matrix Adaboost')

# %% [markdown]
# # Model 1 - Basic ANN

# %%
X_train.shape
# Out:
# (246766, 60)

# %% [markdown]
# ## Model

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)
# def get_model(input_shape):
#     model = Sequential()
#     input_layer = Input(shape=(input_shape,))

#     # Branch 1
#     x1 = Dense(64, activation='relu')(input_layer)
#     x1 = Dense(64, activation='relu')(x1)
#     x1 = Dense(128, activation='relu')(x1)
#     x1 = Dense(256, activation='relu')(x1)

#     # Branch 2
#     x2 = Dense(64, activation='relu')(input_layer)
#     x2 = Dense(64, activation='relu')(x2)
#     x2 = Dense(128, activation='relu')(x2)
#     x2 = Dense(256, activation='relu')(x2)

#     # Concatenate the outputs of the two branches
#     merged = Concatenate()([x1, x2])

#     # Continue with the shared pathway
#     shared_pathway = Dense(512, activation='relu')(merged)

#     # Output layer
#     output_layer = Dense(1, activation='sigmoid')(shared_pathway)

#     # Create the model
#     model = Model(inputs=input_layer, outputs=output_layer)

#     # Compile the model (add optimizer, loss, and metrics as needed)
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

#     return model

# def get_model(input_shape):
#     model = Sequential()
#     model.add(Input(shape=(input_shape,)))
    
#     model.add(Dense(64, activation='relu'))
#     model.add(Dense(64, activation='relu'))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(256, activation='relu'))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(512, activation='relu'))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(1, activation='sigmoid'))
    
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
#     return model

def get_model(input_shape):
    model = Sequential()
    model.add(Input(shape=(input_shape,)))
    
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(128, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

model = get_model(X_train.shape[1])

print(model.summary())
tf.keras.utils.plot_model(model, show_shapes=True,show_layer_names=False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2688
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  dense_3 (Dense)             (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 180289 (704.25 KB)
# Trainable params: 180289 (704.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#load a model and show its architecture
model1 = load_model('../../model/ember_model_ann_64_64_128_256_512_1_dropout_89.h5')
print(model1.summary())
# tf.keras.utils.plot_model(model, show_shapes=True,show_layer_names=False)
# Out:
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_238 (Dense)           (None, 64)                2688
#
#  dense_239 (Dense)           (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_240 (Dense)           (None, 128)               8320
#
#  dense_241 (Dense)           (None, 256)               33024
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_242 (Dense)           (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_243 (Dense)           (None, 1)                 513
#
# =================================================================
# Total params: 180289 (704.25 KB)
# Trainable params: 180289 (704.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ## Fit

# %%
  
#validation accuracy chart



history = model.fit(X_train, y_train, epochs=30, batch_size=2048, validation_data=(X_val, y_val), verbose=1)
# Out:
# Epoch 1/30
# 121/121 [==============================] - 4s 20ms/step - loss: 0.4407 - accuracy: 0.7797 - val_loss: 0.3051 - val_accuracy: 0.8631
# Epoch 2/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2976 - accuracy: 0.8694 - val_loss: 0.2510 - val_accuracy: 0.8917
# Epoch 3/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.2590 - accuracy: 0.8890 - val_loss: 0.2295 - val_accuracy: 0.9017
# Epoch 4/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2405 - accuracy: 0.8982 - val_loss: 0.2133 - val_accuracy: 0.9094
# Epoch 5/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2284 - accuracy: 0.9038 - val_loss: 0.2045 - val_accuracy: 0.9151
# Epoch 6/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2191 - accuracy: 0.9082 - val_loss: 0.1973 - val_accuracy: 0.9185
# Epoch 7/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.2117 - accuracy: 0.9120 - val_loss: 0.1912 - val_accuracy: 0.9210
# Epoch 8/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2056 - accuracy: 0.9144 - val_loss: 0.1868 - val_accuracy: 0.9229
# Epoch 9/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.2014 - accuracy: 0.9169 - val_loss: 0.1837 - val_accuracy: 0.9249
# Epoch 10/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1973 - accuracy: 0.9188 - val_loss: 0.1807 - val_accuracy: 0.9266
# Epoch 11/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1945 - accuracy: 0.9204 - val_loss: 0.1764 - val_accuracy: 0.9287
# Epoch 12/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1918 - accuracy: 0.9213 - val_loss: 0.1746 - val_accuracy: 0.9291
# Epoch 13/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1878 - accuracy: 0.9231 - val_loss: 0.1730 - val_accuracy: 0.9293
# Epoch 14/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1864 - accuracy: 0.9238 - val_loss: 0.1710 - val_accuracy: 0.9315
# Epoch 15/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1844 - accuracy: 0.9247 - val_loss: 0.1710 - val_accuracy: 0.9318
# Epoch 16/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1815 - accuracy: 0.9261 - val_loss: 0.1703 - val_accuracy: 0.9321
# Epoch 17/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1791 - accuracy: 0.9269 - val_loss: 0.1672 - val_accuracy: 0.9324
# Epoch 18/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1781 - accuracy: 0.9280 - val_loss: 0.1647 - val_accuracy: 0.9338
# Epoch 19/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1754 - accuracy: 0.9283 - val_loss: 0.1669 - val_accuracy: 0.9328
# Epoch 20/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1745 - accuracy: 0.9294 - val_loss: 0.1636 - val_accuracy: 0.9335
# Epoch 21/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1731 - accuracy: 0.9291 - val_loss: 0.1625 - val_accuracy: 0.9348
# Epoch 22/30
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1721 - accuracy: 0.9298 - val_loss: 0.1624 - val_accuracy: 0.9355
# Epoch 23/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1701 - accuracy: 0.9308 - val_loss: 0.1613 - val_accuracy: 0.9364
# Epoch 24/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1691 - accuracy: 0.9312 - val_loss: 0.1601 - val_accuracy: 0.9364
# Epoch 25/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1688 - accuracy: 0.9314 - val_loss: 0.1583 - val_accuracy: 0.9372
# Epoch 26/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1668 - accuracy: 0.9324 - val_loss: 0.1587 - val_accuracy: 0.9366
# Epoch 27/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1662 - accuracy: 0.9326 - val_loss: 0.1575 - val_accuracy: 0.9371
# Epoch 28/30
# 121/121 [==============================] - 2s 17ms/step - loss: 0.1642 - accuracy: 0.9329 - val_loss: 0.1579 - val_accuracy: 0.9383
# Epoch 29/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1637 - accuracy: 0.9333 - val_loss: 0.1567 - val_accuracy: 0.9381
# Epoch 30/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1636 - accuracy: 0.9338 - val_loss: 0.1572 - val_accuracy: 0.9383

# %% [markdown]
# ## Predict

# %%
y_pred_ann, y_pred_binary = annModels.predictAnnModel(model,X_test,y_test,threshold = 0.5)
y_train_ann,y_train_binary = annModels.predictAnnModel(model,X_train,y_train,threshold = 0.5)
y_val_ann,y_val_binary = annModels.predictAnnModel(model,X_val,y_val,threshold = 0.5)
# Out:
#    1/3447 [..............................] - ETA: 1:12
# 3447/3447 [==============================] - 5s 1ms/step
# 0.8847740730329438
# 3447/3447 [==============================] - 6s 2ms/step - loss: 3.3794 - accuracy: 0.8848
# 3.379448652267456 0.8847740888595581
# 7712/7712 [==============================] - 10s 1ms/step
# 0.9468079070860653
# 7712/7712 [==============================] - 13s 2ms/step - loss: 0.1344 - accuracy: 0.9468
# 0.1344137042760849 0.9468079209327698
# 1928/1928 [==============================] - 3s 1ms/step
# 0.9382577967969915
# 1928/1928 [==============================] - 3s 2ms/step - loss: 0.1572 - accuracy: 0.9383
# 0.1572212129831314 0.9382578134536743

# %% [markdown]
# ## Graphs

# %%
# confusion matrix    
data_visualization.plotAll(y_test, y_pred_ann,y_pred_binary, history, labels=[0, 1], title='Confusion matrix ANN')
# Out:
# AUC Score: 0.9311094517069314
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89     57489
#            1       0.91      0.85      0.88     52790
#
#     accuracy                           0.88    110279
#    macro avg       0.89      0.88      0.88    110279
# weighted avg       0.89      0.88      0.88    110279

# %% [markdown]
# ## Save

# %%
# save model
model.save('../model/ember_model_ann_64_64_128_256_512_1_dropout_89.h5')
# Out:
# /home/sukhmeet/miniconda3/envs/tf/lib/python3.9/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Stack ANN

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 41) dtype=float32 (created by layer 'input_8')>

# %% [markdown]
# ## Model preparation

# %%
np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)
# def get_model(input_shape,id):
#     model = Sequential()
#     model.add(Input(shape=(input_shape,)))
    
#     model.add(Dense(64, activation='relu',name = 'layer_1_64_'+str(id)))
#     model.add(Dense(64, activation='relu', name = 'layer_2_64_'+str(id)))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(128, activation='relu', name = 'layer_1_128_'+str(id)))
#     model.add(Dense(256, activation='relu', name = 'layer_2_256_'+str(id)))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(512, activation='relu', name = 'layer_1_512_'+str(id)))
#     model.add(Dropout(0.2))
    
#     model.add(Dense(1, activation='sigmoid', name = 'output_layer_'+str(id)))
    
#     model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
#     return model

def get_model(input_shape,id):
    model = Sequential()
    model.add(Input(shape=(input_shape,)))
    
    model.add(Dense(128, activation='relu',name = 'layer_1_128_'+str(id)))
    model.add(Dense(128, activation='relu', name = 'layer_2_128_'+str(id)))
    model.add(Dropout(0.2))
    
    model.add(Dense(256, activation='relu', name = 'layer_1_256_'+str(id)))
    model.add(Dense(512, activation='relu', name = 'layer_2_512_'+str(id)))
    model.add(Dropout(0.2))
    
    model.add(Dense(100, activation='relu', name = 'layer_1_100_'+str(id)))
    model.add(Dropout(0.2))
    
    model.add(Dense(1, activation='sigmoid', name = 'output_layer_'+str(id)))
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# %%
from  ann_visualizer.visualize import ann_viz;
model = get_model(X_train.shape[1],0)
ann_viz(model, title="My first neural network")
# Out:
# Warning: Could not load "/usr/lib/x86_64-linux-gnu/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "/usr/lib/x86_64-linux-gnu/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Format: "pdf" not recognized. Use one of: canon cmap cmapx cmapx_np dot dot_json eps fig gd gd2 gif gv imap imap_np ismap jpe jpeg jpg json json0 mp pdf pic plain plain-ext png pov ps ps2 svg svgz tk vdx vml vmlz vrml wbmp webp x11 xdot xdot1.2 xdot1.4 xdot_json xlib
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/backend/execute.py:91, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      90 try:
# ---> 91     proc.check_returncode()
#      92 except subprocess.CalledProcessError as e:
#
# File ~/miniconda3/envs/tf/lib/python3.9/subprocess.py:460, in CompletedProcess.check_returncode(self)
#     459 if self.returncode:
# --> 460     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     461                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpdf', '-O', 'network.gv']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 3
#       1 from  ann_visualizer.visualize import ann_viz;
#       2 model = get_model(X_train.shape[1],0)
# ----> 3 ann_viz(model, title="My first neural network")
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/ann_visualizer/visualize.py:206, in ann_viz(model, view, filename, title)
#     204 g.edge_attr.update(arrowhead="none", color="#707070");
#     205 if view == True:
# --> 206     g.view()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/rendering.py:185, in Render.view(self, filename, directory, cleanup, quiet, quiet_view)
#     150 @_tools.deprecate_positional_args(supported_number=2)
#     151 def view(self,
#     152          filename: typing.Union[os.PathLike, str, None] = None,
#    (...)
#     155          quiet: bool = False,
#     156          quiet_view: bool = False) -> str:
#     157     """Save the source to file, open the rendered result in a viewer.
#     158
#     159     Convenience short-cut for running ``.render(view=True)``.
#    (...)
#     183         and no way to retrieve the application's exit status.
#     184     """
# --> 185     return self.render(filename=filename, directory=directory, view=True,
#     186                        cleanup=cleanup, quiet=quiet, quiet_view=quiet_view)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/backend/rendering.py:324, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     320     raise exceptions.FileExistsError(f'output file exists: {os.fspath(outfile)!r}')
#     322 cmd += args
# --> 324 execute.run_check(cmd,
#     325                   cwd=filepath.parent if filepath.parent.parts else None,
#     326                   quiet=quiet,
#     327                   capture_output=True)
#     329 return os.fspath(outfile)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/graphviz/backend/execute.py:93, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      91     proc.check_returncode()
#      92 except subprocess.CalledProcessError as e:
# ---> 93     raise CalledProcessError(*e.args)
#      95 return proc
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpdf', '-O', 'network.gv']' returned non-zero exit status 1. [stderr: b'Warning: Could not load "/usr/lib/x86_64-linux-gnu/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.\nWarning: Could not load "/usr/lib/x86_64-linux-gnu/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.\nFormat: "pdf" not recognized. Use one of: canon cmap cmapx cmapx_np dot dot_json eps fig gd gd2 gif gv imap imap_np ismap jpe jpeg jpg json json0 mp pdf pic plain plain-ext png pov ps ps2 svg svgz tk vdx vml vmlz vrml wbmp webp x11 xdot xdot1.2 xdot1.4 xdot_json xlib\n']

# %%
total_models = 4

models = [get_model(X_train.shape[1],i) for i in range(total_models)]
# models = [load_model('../../model/ember_model_ann_64_64_128_256_512_1_dropout_89.h5') for _ in range(total_models) ]
history_stacked = []

for model in models:
  history = model.fit(X_train, y_train, epochs=30, batch_size=2048, validation_data=(X_val, y_val), verbose=1)
  history_stacked.append(history)
# Out:
# Epoch 1/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.3422 - accuracy: 0.8435 - val_loss: 0.2328 - val_accuracy: 0.9015
# Epoch 2/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.2350 - accuracy: 0.9015 - val_loss: 0.2025 - val_accuracy: 0.9169
# Epoch 3/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.2072 - accuracy: 0.9145 - val_loss: 0.1862 - val_accuracy: 0.9239
# Epoch 4/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1912 - accuracy: 0.9216 - val_loss: 0.1731 - val_accuracy: 0.9299
# Epoch 5/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1806 - accuracy: 0.9261 - val_loss: 0.1663 - val_accuracy: 0.9336
# Epoch 6/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1730 - accuracy: 0.9297 - val_loss: 0.1619 - val_accuracy: 0.9355
# Epoch 7/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1678 - accuracy: 0.9318 - val_loss: 0.1559 - val_accuracy: 0.9382
# Epoch 8/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1608 - accuracy: 0.9348 - val_loss: 0.1539 - val_accuracy: 0.9388
# Epoch 9/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1557 - accuracy: 0.9372 - val_loss: 0.1499 - val_accuracy: 0.9420
# Epoch 10/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1521 - accuracy: 0.9388 - val_loss: 0.1459 - val_accuracy: 0.9419
# Epoch 11/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1490 - accuracy: 0.9402 - val_loss: 0.1447 - val_accuracy: 0.9417
# Epoch 12/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1443 - accuracy: 0.9418 - val_loss: 0.1428 - val_accuracy: 0.9441
# Epoch 13/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1426 - accuracy: 0.9430 - val_loss: 0.1430 - val_accuracy: 0.9434
# Epoch 14/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1396 - accuracy: 0.9438 - val_loss: 0.1398 - val_accuracy: 0.9460
# Epoch 15/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1371 - accuracy: 0.9451 - val_loss: 0.1381 - val_accuracy: 0.9462
# Epoch 16/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1339 - accuracy: 0.9462 - val_loss: 0.1371 - val_accuracy: 0.9464
# Epoch 17/30
# 121/121 [==============================] - 2s 18ms/step - loss: 0.1321 - accuracy: 0.9474 - val_loss: 0.1382 - val_accuracy: 0.9463
# Epoch 18/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1319 - accuracy: 0.9472 - val_loss: 0.1356 - val_accuracy: 0.9480
# Epoch 19/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1288 - accuracy: 0.9477 - val_loss: 0.1362 - val_accuracy: 0.9475
# Epoch 20/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1278 - accuracy: 0.9483 - val_loss: 0.1354 - val_accuracy: 0.9468
# Epoch 21/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1260 - accuracy: 0.9493 - val_loss: 0.1326 - val_accuracy: 0.9491
# Epoch 22/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1236 - accuracy: 0.9506 - val_loss: 0.1327 - val_accuracy: 0.9492
# Epoch 23/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1221 - accuracy: 0.9511 - val_loss: 0.1346 - val_accuracy: 0.9484
# Epoch 24/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.1208 - accuracy: 0.9513 - val_loss: 0.1372 - val_accuracy: 0.9484
# Epoch 25/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1187 - accuracy: 0.9523 - val_loss: 0.1326 - val_accuracy: 0.9498
# Epoch 26/30
# 121/121 [==============================] - 2s 20ms/step - loss: 0.
30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1215 - accuracy: 0.9509 - val_loss: 0.1302 - val_accuracy: 0.9496
# Epoch 24/30
# 121/121 [==============================] - 2s 19ms/step - loss: 0.1201 - accuracy: 0.9522 - val_loss: 0.1319 - val_accuracy: 0.9496
# Epoch 25/30
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1182 - accuracy: 0.9529 - val_loss: 0.1312 - val_accuracy: 0.9495
# Epoch 26/30
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1173 - accuracy: 0.9536 - val_loss: 0.1297 - val_accuracy: 0.9505
# Epoch 27/30
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1164 - accuracy: 0.9539 - val_loss: 0.1288 - val_accuracy: 0.9511
# Epoch 28/30
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1142 - accuracy: 0.9541 - val_loss: 0.1283 - val_accuracy: 0.9514
# Epoch 29/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1144 - accuracy: 0.9542 - val_loss: 0.1297 - val_accuracy: 0.9503
# Epoch 30/30
# 121/121 [==============================] - 3s 21ms/step - loss: 0.1126 - accuracy: 0.9553 - val_loss: 0.1277 - val_accuracy: 0.9523

# %%
for layer in models[3].layers:
  print(layer.name)
# Out:
# layer_1_128_3
# layer_2_128_3
# dropout_9
# layer_1_256_3
# layer_2_512_3
# dropout_10
# layer_1_100_3
# dropout_11
# output_layer_3

# %%
X_train.shape
# Out:
# (246766, 60)

# %%
models[0]._name = 'model_' + str(1)
print(models[0].summary())
tf.keras.utils.plot_model(models[0], show_shapes=True,show_layer_names=False)	# compile
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer_1_128_0 (Dense)       (None, 128)               7808
#
#  layer_2_128_0 (Dense)       (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  layer_1_256_0 (Dense)       (None, 256)               33024
#
#  layer_2_512_0 (Dense)       (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  layer_1_100_0 (Dense)       (None, 100)               51300
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  output_layer_0 (Dense)      (None, 1)                 101
#
# =================================================================
# Total params: 240329 (938.79 KB)
# Trainable params: 240329 (938.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
models[1]._name
# Out:
# 'sequential_1'

# %%
for model in models:
  print(model.output)
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='output_layer_0/Sigmoid:0', description="created by layer 'output_layer_0'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='output_layer_1/Sigmoid:0', description="created by layer 'output_layer_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='output_layer_2/Sigmoid:0', description="created by layer 'output_layer_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='output_layer_3/Sigmoid:0', description="created by layer 'output_layer_3'")

# %% [markdown]
# ## Stacking

# %%
# define stacked model from multiple member input models
def define_stacked_model(members):
  for i in range(len(members)):
    model = members[i]
    # model._name = 'model_' + str(i+1)

    for layer in model.layers:
      layer.trainable = False
      # layer._name = 'ensemble_' + str(i+1) + '_' + layer.name
      # tf.keras.utils.plot_model(stacked_model, show_shapes=True,show_layer_names=False)	# compile
      # plt.show()

  ensemble_visible = [model.input for model in members]
  ensemble_outputs = [model.output for model in members]
  merge = concatenate(ensemble_outputs)
  hidden = Dense(8, activation='relu')(merge)
  # hidden = Dense(16, activation='relu')(hidden)
  # dropout = Dropout(0.2)(hidden)
  # hidden = Dense(10, activation='relu')(dropout)
  output = Dense(1, activation='sigmoid')(hidden)
  model = Model(inputs=ensemble_visible, outputs=output)
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model

# %%
stacked_model = define_stacked_model(models)
tf.keras.utils.plot_model(stacked_model, show_shapes=True,show_layer_names=False)	# compile

# %%
stacked_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 60)]                 0         []
#
#  input_2 (InputLayer)        [(None, 60)]                 0         []
#
#  input_3 (InputLayer)        [(None, 60)]                 0         []
#
#  input_4 (InputLayer)        [(None, 60)]                 0         []
#
#  layer_1_128_0 (Dense)       (None, 128)                  7808      ['input_1[0][0]']
#
#  layer_1_128_1 (Dense)       (None, 128)                  7808      ['input_2[0][0]']
#
#  layer_1_128_2 (Dense)       (None, 128)                  7808      ['input_3[0][0]']
#
#  layer_1_128_3 (Dense)       (None, 128)                  7808      ['input_4[0][0]']
#
#  layer_2_128_0 (Dense)       (None, 128)                  16512     ['layer_1_128_0[0][0]']
#
#  layer_2_128_1 (Dense)       (None, 128)                  16512     ['layer_1_128_1[0][0]']
#
#  layer_2_128_2 (Dense)       (None, 128)                  16512     ['layer_1_128_2[0][0]']
#
#  layer_2_128_3 (Dense)       (None, 128)                  16512     ['layer_1_128_3[0][0]']
#
#  dropout (Dropout)           (None, 128)                  0         ['layer_2_128_0[0][0]']
#
#  dropout_3 (Dropout)         (None, 128)                  0         ['layer_2_128_1[0][0]']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['layer_2_128_2[0][0]']
#
#  dropout_9 (Dropout)         (None, 128)                  0         ['layer_2_128_3[0][0]']
#
#  layer_1_256_0 (Dense)       (None, 256)                  33024     ['dropout[0][0]']
#
#  layer_1_256_1 (Dense)       (None, 256)                  33024     ['dropout_3[0][0]']
#
#  layer_1_256_2 (Dense)       (None, 256)                  33024     ['dropout_6[0][0]']
#
#  layer_1_256_3 (Dense)       (None, 256)                  33024     ['dropout_9[0][0]']
#
#  layer_2_512_0 (Dense)       (None, 512)                  131584    ['layer_1_256_0[0][0]']
#
#  layer_2_512_1 (Dense)       (None, 512)                  131584    ['layer_1_256_1[0][0]']
#
#  layer_2_512_2 (Dense)       (None, 512)                  131584    ['layer_1_256_2[0][0]']
#
#  layer_2_512_3 (Dense)       (None, 512)                  131584    ['layer_1_256_3[0][0]']
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['layer_2_512_0[0][0]']
#
#  dropout_4 (Dropout)         (None, 512)                  0         ['layer_2_512_1[0][0]']
#
#  dropout_7 (Dropout)         (None, 512)                  0         ['layer_2_512_2[0][0]']
#
#  dropout_10 (Dropout)        (None, 512)                  0         ['layer_2_512_3[0][0]']
#
#  layer_1_100_0 (Dense)       (None, 100)                  51300     ['dropout_1[0][0]']
#
#  layer_1_100_1 (Dense)       (None, 100)                  51300     ['dropout_4[0][0]']
#
#  layer_1_100_2 (Dense)       (None, 100)                  51300     ['dropout_7[0][0]']
#
#  layer_1_100_3 (Dense)       (None, 100)                  51300     ['dropout_10[0][0]']
#
#  dropout_2 (Dropout)         (None, 100)                  0         ['layer_1_100_0[0][0]']
#
#  dropout_5 (Dropout)         (None, 100)                  0         ['layer_1_100_1[0][0]']
#
#  dropout_8 (Dropout)         (None, 100)                  0         ['layer_1_100_2[0][0]']
#
#  dropout_11 (Dropout)        (None, 100)                  0         ['layer_1_100_3[0][0]']
#
#  output_layer_0 (Dense)      (None, 1)                    101       ['dropout_2[0][0]']
#
#  output_layer_1 (Dense)      (None, 1)                    101       ['dropout_5[0][0]']
#
#  output_layer_2 (Dense)      (None, 1)                    101       ['dropout_8[0][0]']
#
#  output_layer_3 (Dense)      (None, 1)                    101       ['dropout_11[0][0]']
#
#  concatenate (Concatenate)   (None, 4)                    0         ['output_layer_0[0][0]',
#                                                                      'output_layer_1[0][0]',
#                                                                      'output_layer_2[0][0]',
#                                                                      'output_layer_3[0][0]']
#
#  dense (Dense)               (None, 8)                    40        ['concatenate[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    9         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 961365 (3.67 MB)
# Trainable params: 49 (196.00 Byte)
# Non-trainable params: 961316 (3.67 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fit

# %%
# fit a stacked model
def fit_stacked_model(model, X_train, y_train, X_val, y_val):
	# prepare input data
	X = [X_train for _ in range(len(model.input))]
	X_v = [X_val for _ in range(len(model.input))]
	# encode output data
	# y_train_enc = to_categorical(y_train)
	y_train_enc = y_train
	# fit model
	history = model.fit(X, y_train_enc, epochs=15, batch_size=2048, validation_data=(X_v, y_val), verbose=1)
	return history

# %%
# fit stacked model on test dataset
history = fit_stacked_model(stacked_model, X_train, y_train, X_val, y_val)
# Out:
# Epoch 1/15
# 121/121 [==============================] - 3s 21ms/step - loss: 0.5392 - accuracy: 0.9014 - val_loss: 0.4489 - val_accuracy: 0.9384
# Epoch 2/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.3752 - accuracy: 0.9538 - val_loss: 0.3202 - val_accuracy: 0.9493
# Epoch 3/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.2651 - accuracy: 0.9619 - val_loss: 0.2361 - val_accuracy: 0.9523
# Epoch 4/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1944 - accuracy: 0.9656 - val_loss: 0.1863 - val_accuracy: 0.9538
# Epoch 5/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1518 - accuracy: 0.9671 - val_loss: 0.1581 - val_accuracy: 0.9545
# Epoch 6/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1267 - accuracy: 0.9679 - val_loss: 0.1424 - val_accuracy: 0.9552
# Epoch 7/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1118 - accuracy: 0.9683 - val_loss: 0.1336 - val_accuracy: 0.9556
# Epoch 8/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.1028 - accuracy: 0.9686 - val_loss: 0.1289 - val_accuracy: 0.9558
# Epoch 9/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0972 - accuracy: 0.9685 - val_loss: 0.1264 - val_accuracy: 0.9560
# Epoch 10/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0935 - accuracy: 0.9686 - val_loss: 0.1251 - val_accuracy: 0.9563
# Epoch 11/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0908 - accuracy: 0.9688 - val_loss: 0.1246 - val_accuracy: 0.9563
# Epoch 12/15
# 121/121 [==============================] - 2s 16ms/step - loss: 0.0893 - accuracy: 0.9689 - val_loss: 0.1243 - val_accuracy: 0.9565
# Epoch 13/15
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0881 - accuracy: 0.9692 - val_loss: 0.1243 - val_accuracy: 0.9564
# Epoch 14/15
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0879 - accuracy: 0.9690 - val_loss: 0.1245 - val_accuracy: 0.9564
# Epoch 15/15
# 121/121 [==============================] - 2s 17ms/step - loss: 0.0869 - accuracy: 0.9691 - val_loss: 0.1245 - val_accuracy: 0.9565

# %% [markdown]
# ## Predict

# %%
# make a prediction with a stacked model
def predict_stacked_model(model, inputX):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# make prediction
	return model.predict(X, verbose=1)

# %%
# make predictions and evaluate
threshold = 0.5
y_pred = predict_stacked_model(stacked_model, X_test)
y_pred_binary = np.where(y_pred >threshold,1,0)
y_pred_binary = np.array(y_pred_binary)
print(accuracy_score(y_test, y_pred_binary))
metrics = model.evaluate(X_test, y_test, verbose=1)
print(*metrics)
# Out:
# 3447/3447 [==============================] - 7s 2ms/step
# 0.9003255379537355
# 3447/3447 [==============================] - 6s 2ms/step - loss: 3.4034 - accuracy: 0.8787
# 3.4033544063568115 0.8787257671356201

# %%
for model in models:
  annModels.predictAnnModel(model,X_test,y_test,threshold = 0.5)
# Out:
# 3447/3447 [==============================] - 4s 1ms/step
# 0.8913029679268039
# 3447/3447 [==============================] - 6s 2ms/step - loss: 2.7641 - accuracy: 0.8913
# 2.764122247695923 0.8913029432296753
# 3447/3447 [==============================] - 4s 1ms/step
# 0.8965895592089156
# 3447/3447 [==============================] - 6s 2ms/step - loss: 1.7900 - accuracy: 0.8966
# 1.7900474071502686 0.8965895771980286
# 3447/3447 [==============================] - 4s 1ms/step
# 0.8899518494001578
# 3447/3447 [==============================] - 6s 2ms/step - loss: 3.3029 - accuracy: 0.8900
# 3.3029134273529053 0.8899518251419067
# 3447/3447 [==============================] - 5s 1ms/step
# 0.8787257773465483
# 3447/3447 [==============================] - 6s 2ms/step - loss: 3.4034 - accuracy: 0.8787
# 3.4033544063568115 0.8787257671356201

# %% [markdown]
# ## Graphs

# %%
data_visualization.plotAll(y_test,y_pred, y_pred_binary, history, labels=[0, 1], title='Confusion matrix for Stacked',save = True)
# Out:
# AUC Score: 0.9581909669692412
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91     57489
#            1       0.92      0.87      0.89     52790
#
#     accuracy                           0.90    110279
#    macro avg       0.90      0.90      0.90    110279
# weighted avg       0.90      0.90      0.90    110279

# %% [markdown]
# # Parameter Search (Grid)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import roc_curve, auc, roc_auc_score
from keras_tuner.tuners import RandomSearch

# Define a function to build your model
def build_model(hp):
    model = keras.Sequential()
    
    # Define a tunable hyperparameter for the number of units in the first layer
    hp_units = hp.Int('units', min_value=100, max_value=200, step=32)
    
    model.add(layers.Dense(units=hp_units, input_dim=X_train.shape[1], activation='relu'))
    
    # Define a tunable hyperparameter for the number of hidden layers
    hp_layers = hp.Int('num_layers', min_value=3, max_value=10)
    
    # Add hidden layers with tunable number of units
    for i in range(hp_layers):
        model.add(layers.Dense(units=hp_units, activation='relu'))
    
    model.add(layers.Dense(1, activation='sigmoid'))
    
    # Compile the model with a tunable learning rate
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-3, 1e-4])
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    return model

# Initialize the tuner (RandomSearch in this case)
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=2,  # Number of hyperparameter combinations to try
    directory='my_tuner_dir',  # Directory to save the search results
    project_name='my_ann_hyperparameeter_search'  # Name of the tuning project
)

# Decrease the batch size
batch_size = 1024

# Search for the best hyperparameters
tuner.search(X_train, y_train,
             epochs=10,  # You can adjust the number of epochs
             validation_data=(X_val, y_val),
             batch_size=batch_size)  # Provide your validation data

# Get the best hyperparameters and build the final model
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.hypermodel.build(best_hyperparameters)

# Train the final model with the best hyperparameters
best_model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val), batch_size=batch_size)

# Evaluate the final model on your test data
test_loss, test_accuracy = best_model.evaluate(X_test, y_test)

# Print the best hyperparameters
print("Best hyperparameters:")
print(best_hyperparameters)

# Print the test accuracy
print(f"Test accuracy: {test_accuracy}")
# Out:
# Using TensorFlow backend
# Reloading Tuner from my_tuner_dir/my_ann_hyperparameeter_search/tuner0.json
# Epoch 1/100
# 241/241 [==============================] - 6s 21ms/step - loss: 0.3799 - accuracy: 0.8198 - val_loss: 0.2559 - val_accuracy: 0.8920
# Epoch 2/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.2305 - accuracy: 0.9034 - val_loss: 0.2145 - val_accuracy: 0.9111
# Epoch 3/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.2004 - accuracy: 0.9181 - val_loss: 0.1961 - val_accuracy: 0.9212
# Epoch 4/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1813 - accuracy: 0.9273 - val_loss: 0.1862 - val_accuracy: 0.9263
# Epoch 5/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1679 - accuracy: 0.9332 - val_loss: 0.1793 - val_accuracy: 0.9291
# Epoch 6/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1595 - accuracy: 0.9372 - val_loss: 0.1708 - val_accuracy: 0.9340
# Epoch 7/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1503 - accuracy: 0.9409 - val_loss: 0.1719 - val_accuracy: 0.9332
# Epoch 8/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1431 - accuracy: 0.9444 - val_loss: 0.1698 - val_accuracy: 0.9343
# Epoch 9/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1375 - accuracy: 0.9467 - val_loss: 0.1645 - val_accuracy: 0.9368
# Epoch 10/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.1313 - accuracy: 0.9491 - val_loss: 0.1550 - val_accuracy: 0.9412
# Epoch 11/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1270 - accuracy: 0.9511 - val_loss: 0.1525 - val_accuracy: 0.9416
# Epoch 12/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1245 - accuracy: 0.9522 - val_loss: 0.1528 - val_accuracy: 0.9430
# Epoch 13/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1176 - accuracy: 0.9549 - val_loss: 0.1573 - val_accuracy: 0.9413
# Epoch 14/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1165 - accuracy: 0.9554 - val_loss: 0.1498 - val_accuracy: 0.9449
# Epoch 15/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1123 - accuracy: 0.9572 - val_loss: 0.1507 - val_accuracy: 0.9437
# Epoch 16/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1079 - accuracy: 0.9591 - val_loss: 0.1518 - val_accuracy: 0.9442
# Epoch 17/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1055 - accuracy: 0.9598 - val_loss: 0.1531 - val_accuracy: 0.9448
# Epoch 18/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1020 - accuracy: 0.9612 - val_loss: 0.1510 - val_accuracy: 0.9453
# Epoch 19/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.1000 - accuracy: 0.9622 - val_loss: 0.1488 - val_accuracy: 0.9476
# Epoch 20/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0966 - accuracy: 0.9641 - val_loss: 0.1543 - val_accuracy: 0.9455
# Epoch 21/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0955 - accuracy: 0.9641 - val_loss: 0.1547 - val_accuracy: 0.9456
# Epoch 22/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0919 - accuracy: 0.9659 - val_loss: 0.1514 - val_accuracy: 0.9475
# Epoch 23/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.0910 - accuracy: 0.9660 - val_loss: 0.1483 - val_accuracy: 0.9479
# Epoch 24/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.0876 - accuracy: 0.9675 - val_loss: 0.1518 - val_accuracy: 0.9484
# Epoch 25/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0849 - accuracy: 0.9685 - val_loss: 0.1674 - val_accuracy: 0.9441
# Epoch 26/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.
100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.2062 - val_accuracy: 0.9527
# Epoch 88/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0334 - accuracy: 0.9881 - val_loss: 0.2245 - val_accuracy: 0.9496
# Epoch 89/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0339 - accuracy: 0.9876 - val_loss: 0.2079 - val_accuracy: 0.9510
# Epoch 90/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.0343 - accuracy: 0.9874 - val_loss: 0.2276 - val_accuracy: 0.9500
# Epoch 91/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.0337 - accuracy: 0.9881 - val_loss: 0.2079 - val_accuracy: 0.9519
# Epoch 92/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0346 - accuracy: 0.9875 - val_loss: 0.2199 - val_accuracy: 0.9520
# Epoch 93/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0326 - accuracy: 0.9882 - val_loss: 0.2072 - val_accuracy: 0.9537
# Epoch 94/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0334 - accuracy: 0.9880 - val_loss: 0.2198 - val_accuracy: 0.9524
# Epoch 95/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0313 - accuracy: 0.9885 - val_loss: 0.2240 - val_accuracy: 0.9520
# Epoch 96/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0335 - accuracy: 0.9877 - val_loss: 0.2092 - val_accuracy: 0.9534
# Epoch 97/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0316 - accuracy: 0.9885 - val_loss: 0.2184 - val_accuracy: 0.9524
# Epoch 98/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0332 - accuracy: 0.9880 - val_loss: 0.2279 - val_accuracy: 0.9516
# Epoch 99/100
# 241/241 [==============================] - 5s 19ms/step - loss: 0.0314 - accuracy: 0.9884 - val_loss: 0.2164 - val_accuracy: 0.9531
# Epoch 100/100
# 241/241 [==============================] - 5s 20ms/step - loss: 0.0328 - accuracy: 0.9882 - val_loss: 0.2121 - val_accuracy: 0.9533
# 3447/3447 [==============================] - 8s 2ms/step - loss: 35.8350 - accuracy: 0.8790
# Best hyperparameters:
# <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x7f3041602a60>
# Test accuracy: 0.8789706230163574

# %%
# print best parameter
print("Best parameter")
print(best_hyperparameters.values)
# Out:
# Best parameter
# {'units': 192, 'num_layers': 9, 'learning_rate': 0.0001}

# %%
print(best_model.summary())
tf.keras.utils.plot_model(best_model, show_shapes=True,show_layer_names=False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 192)               11712
#
#  dense_10 (Dense)            (None, 192)               37056
#
#  dense_11 (Dense)            (None, 192)               37056
#
#  dense_12 (Dense)            (None, 192)               37056
#
#  dense_13 (Dense)            (None, 192)               37056
#
#  dense_14 (Dense)            (None, 192)               37056
#
#  dense_15 (Dense)            (None, 192)               37056
#
#  dense_16 (Dense)            (None, 192)               37056
#
#  dense_17 (Dense)            (None, 192)               37056
#
#  dense_18 (Dense)            (None, 192)               37056
#
#  dense_19 (Dense)            (None, 1)                 193
#
# =================================================================
# Total params: 345409 (1.32 MB)
# Trainable params: 345409 (1.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# #  Ensemble Model - Adaboost

# %% [markdown]
# ## Model

# %%
def get_model():
    model = Sequential()
    # X_train.shape = (90164, 41)
    model.add(Dense(100, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model



model= KerasClassifier(model=get_model, epochs=50, batch_size=2048, verbose=1)

ada_model = AdaBoostClassifier(estimator=model, n_estimators=10, random_state=42, algorithm='SAMME')

# pipeline = Pipeline([('transformer', StandardScaler()), ('estimator', ada_model)])

# %% [markdown]
# ## Training

# %%
# pipeline.fit(X_train, y_train)

ada_model.fit(X_train, y_train)
# Out:
# Epoch 1/100
# 121/121 [==============================] - 3s 15ms/step - loss: 2.8023e-06 - accuracy: 0.5397
# Epoch 2/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.
100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7826e-06 - accuracy: 0.5655
# Epoch 92/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7798e-06 - accuracy: 0.5677
# Epoch 93/100
# 121/121 [==============================] - 2s 15ms/step - loss: 2.7820e-06 - accuracy: 0.5662
# Epoch 94/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7824e-06 - accuracy: 0.5647
# Epoch 95/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7822e-06 - accuracy: 0.5665
# Epoch 96/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7808e-06 - accuracy: 0.5674
# Epoch 97/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7780e-06 - accuracy: 0.5667
# Epoch 98/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7821e-06 - accuracy: 0.5667
# Epoch 99/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7793e-06 - accuracy: 0.5666
# Epoch 100/100
# 121/121 [==============================] - 2s 14ms/step - loss: 2.7775e-06 - accuracy: 0.5676
# 121/121 [==============================] - 0s 2ms/step
# AdaBoostClassifier(algorithm='SAMME',
#                    estimator=KerasClassifier(batch_size=2048, epochs=100, model=<function get_model at 0x7fbb88490820>),
#                    n_estimators=10, random_state=42)

# %% [markdown]
# ## Save

# %%
joblib.dump(ada_model, '../model/ember_model_adaboost_pca.joblib')
# Out:
# INFO:tensorflow:Assets written to: ram://bcbaa4f12fb64c1ca8730ee900be3b93/assets
# INFO:tensorflow:Assets written to: ram://bcbaa4f12fb64c1ca8730ee900be3b93/assets
# INFO:tensorflow:Assets written to: ram://4cd752a832cb46b49f0cb0ddfd871efa/assets
# INFO:tensorflow:Assets written to: ram://4cd752a832cb46b49f0cb0ddfd871efa/assets
# INFO:tensorflow:Assets written to: ram://5b63748ab03d4f52902d00de6e9eb328/assets
# INFO:tensorflow:Assets written to: ram://5b63748ab03d4f52902d00de6e9eb328/assets
# INFO:tensorflow:Assets written to: ram://2e35c57ab2324df58460eb5a52be3f09/assets
# INFO:tensorflow:Assets written to: ram://2e35c57ab2324df58460eb5a52be3f09/assets
# INFO:tensorflow:Assets written to: ram://f4af6196dd084232811608b269220bdd/assets
# INFO:tensorflow:Assets written to: ram://f4af6196dd084232811608b269220bdd/assets
# INFO:tensorflow:Assets written to: ram://2ae5a879aeee428a917d47acf68ffd34/assets
# INFO:tensorflow:Assets written to: ram://2ae5a879aeee428a917d47acf68ffd34/assets
# INFO:tensorflow:Assets written to: ram://c3656765dfe841bd91b874283e440fd8/assets
# INFO:tensorflow:Assets written to: ram://c3656765dfe841bd91b874283e440fd8/assets
# INFO:tensorflow:Assets written to: ram://a4451a3c75bf49248c54a12b5241a20e/assets
# INFO:tensorflow:Assets written to: ram://a4451a3c75bf49248c54a12b5241a20e/assets
# INFO:tensorflow:Assets written to: ram://d21c5ab88a6b4c4b97cf7ff7d34aa8e5/assets
# INFO:tensorflow:Assets written to: ram://d21c5ab88a6b4c4b97cf7ff7d34aa8e5/assets
# INFO:tensorflow:Assets written to: ram://85332ace76b14c338f7c665a730c9e92/assets
# INFO:tensorflow:Assets written to: ram://85332ace76b14c338f7c665a730c9e92/assets
# ['../model/ember_model_adaboost_pca.joblib']

# %% [markdown]
# ## Load model

# %%
model = joblib.load('../model/ember_model_adaboost.joblib')

# %% [markdown]
# ## Predict

# %%
y_pred = ada_model.predict(X_test)
# Out:
# 22/54 [===========>..................] - ETA: 0s
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Graphs

# %%
def plot_confusion_matrix(y_true, y_pred, labels, title):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)

    
    plt.figure(figsize=(10, 7))
    sns.heatmap(df_cm, annot=True, fmt='g')
    sns.set(font_scale=2)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
# accuracy
print(accuracy_score(y_test, y_pred.round()))

# confusion matrix
plot_confusion_matrix(y_test, y_pred.round(), labels=[0, 1], title='Confusion matrix Adaboost')

data_visualization.plot_confusion_matrix(y_test, y_pred.round(), labels=[0, 1], title='Confusion matrix Adaboost')
data_visualization.classification_report_display(y_test, y_pred.round())
# Out:
# 0.8621587065533782

# %% [markdown]
# ### Learning curves

# %%
# train_sizes, train_scores, test_scores = learning_curve(ada_model, X_train, y_train, cv=5, scoring='accuracy', n_jobs=-1, train_sizes=np.linspace(0.01, 1.0, 50), verbose=1,n_iter=10)
# plt.plot(train_sizes,np.mean(train_scores,axis=1))

# %% [markdown]
# # XGBoost

# %%
# write code for xgboost
xgb = XGBClassifier(n_estimators=100, n_jobs=50, random_state=42, verbose=1, criterion='entropy',warm_start=True)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(criterion='entropy', n_jobs=50, random_state=42, verbose=1,
#               warm_start=True)

# %%
#predict
y_pred_xgboost = xgb.predict(X_test)

y_train_xgboost = xgb.predict(X_train)

# %%
accuracy = accuracy_score(y_test, y_pred_xgboost)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8156040587963257

# %% [markdown]
# # CNN

# %% [markdown]
# ## Model

# %%
X_train.columns
# Out:
# Index(['.text_size', '.text_entropy', '.text_vsize', '.data_size',
#        '.data_entropy', '.data_vsize', '.rsrc_size', '.rsrc_entropy',
#        '.rsrc_vsize', 'machine', 'subsystem', 'general_size', 'general_vsize',
#        'general_has_debug', 'general_exports', 'general_imports',
#        'general_has_relocations', 'general_has_resources',
#        'general_has_signature', 'general_has_tls', 'general_symbols',
#        'strings_numstrings', 'strings_avlength', 'strings_printables',
#        'strings_entropy', 'strings_paths', 'strings_urls', 'strings_registry',
#        'strings_MZ', 'coff_timestamp', 'optional_major_image_version',
#        'optional_minor_image_version', 'optional_major_linker_version',
#        'optional_minor_linker_version',
#        'optional_major_operating_system_version',
#        'optional_minor_operating_system_version',
#        'optional_major_subsystem_version', 'optional_minor_subsystem_version',
#        'optional_sizeof_code', 'optional_sizeof_headers',
#        'optional_sizeof_heap_commit'],
#       dtype='object')

# %%
def get_cnn_model(input_shape):
    input_shape = (input_shape, 1)

    model = Sequential()
    model.add(Conv1D(128, kernel_size=3, strides = 2, kernel_regularizer=l2(0.01), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))

    model.add(Conv1D(256, kernel_size=3, strides=1, padding='same', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))

    model.add(Conv1D(256, kernel_size=3, strides=1, padding='same', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # max pooling and then flatten
    model.add(MaxPooling1D(pool_size=3, strides=2, padding='same'))
    model.add(Flatten())

    # fully connected layer
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))

    # output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    # model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

    # Print the model summary
    print(model.summary())

    return model

model_cnn =get_cnn_model(X_train.shape[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 20, 128)           512
#
#  batch_normalization (Batch  (None, 20, 128)           512
#  Normalization)
#
#  activation (Activation)     (None, 20, 128)           0
#
#  max_pooling1d (MaxPooling1  (None, 10, 128)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           98560
#
#  batch_normalization_1 (Bat  (None, 10, 256)           1024
#  chNormalization)
#
#  activation_1 (Activation)   (None, 10, 256)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 256)            196864
#
#  batch_normalization_2 (Bat  (None, 5, 256)            1024
#  chNormalization)
#
#  activation_2 (Activation)   (None, 5, 256)            0
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 256)            0
#  g1D)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense_6 (Dense)             (None, 100)               76900
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_7 (Dense)             (None, 100)               10100
#
#  dropout_4 (Dropout)         (None, 100)               0
#
#  dense_8 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 385597 (1.47 MB)
# Trainable params: 384317 (1.47 MB)
# Non-trainable params: 1280 (5.00 KB)
# _________________________________________________________________
# None

# %%
import visualkeras
visualkeras.layered_view(model_cnn)# display using your system viewer
# visualkeras.layered_view(model_cnn, to_file='output.png') # write to disk
# visualkeras.layered_view(model_cnn, to_file='output.png').show() # write and show

visualkeras.layered_view(model_cnn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 import visualkeras
# ----> 2 visualkeras.layered_view(model_cnn)# display using your system viewer
#       3 # visualkeras.layered_view(model_cnn, to_file='output.png') # write to disk
#       4 # visualkeras.layered_view(model_cnn, to_file='output.png').show() # write and show
#       6 visualkeras.layered_view(model_cnn)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/visualkeras/layered.py:100, in layered_view(model, to_file, min_z, min_xy, max_z, max_xy, scale_z, scale_xy, type_ignore, index_ignore, color_map, one_dim_orientation, background_fill, draw_volume, padding, spacing, draw_funnel, shade_step, legend, font, font_color)
#      98     x = min(max(shape[1] * scale_xy, x), max_xy)
#      99     y = min(max(shape[2] * scale_xy, y), max_xy)
# --> 100     z = min(max(z), max_z)
#     101 elif len(shape) == 2:
#     102     if one_dim_orientation == 'x':
#
# TypeError: 'int' object is not iterable

# %%
history_cnn = model_cnn.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=70, batch_size=2048)
# Out:
# Epoch 1/70
# 121/121 [==============================] - 13s 99ms/step - loss: 4.7037 - accuracy: 0.7434 - val_loss: 4.7578 - val_accuracy: 0.5134
# Epoch 2/70
# 121/121 [==============================] - 12s 96ms/step - loss: 4.3926 - accuracy: 0.8172 - val_loss: 4.5525 - val_accuracy: 0.5195
# Epoch 3/70
# 121/121 [==============================] - 12s 98ms/step - loss: 4.1629 - accuracy: 0.8390 - val_loss: 4.2040 - val_accuracy: 0.7768
# Epoch 4/70
# 121/121 [==============================] - 12s 97ms/step - loss: 3.9557 - accuracy: 0.8539 - val_loss: 3.9070 - val_accuracy: 0.8384
# Epoch 5/70
# 121/121 [==============================] - 12s 97ms/step - loss: 3.7644 - accuracy: 0.8638 - val_loss: 3.6805 - val_accuracy: 0.8689
# Epoch 6/70
# 121/121 [==============================] - 11s 95ms/step - loss: 3.5868 - accuracy: 0.8707 - val_loss: 3.4838 - val_accuracy: 0.8842
# Epoch 7/70
# 121/121 [==============================] - 13s 111ms/step - loss: 0.3755 - accuracy: 0.9357 - val_loss: 0.3826 - val_accuracy: 0.9309
# Epoch 66/70
# 121/121 [==============================] - 14s 113ms/step - loss: 0.3621 - accuracy: 0.9379 - val_loss: 0.4809 - val_accuracy: 0.8837
# Epoch 67/70
# 121/121 [==============================] - 13s 110ms/step - loss: 0.3575 - accuracy: 0.9358 - val_loss: 0.3846 - val_accuracy: 0.9237
# Epoch 68/70
# 121/121 [==============================] - 14s 112ms/step - loss: 0.3807 - accuracy: 0.9208 - val_loss: 0.3808 - val_accuracy: 0.9162
# Epoch 69/70
# 121/121 [==============================] - 13s 112ms/step - loss: 0.3374 - accuracy: 0.9381 - val_loss: 0.3535 - val_accuracy: 0.9291
# Epoch 70/70
# 121/121 [==============================] - 14s 113ms/step - loss: 0.3315 - accuracy: 0.9382 - val_loss: 0.3378 - val_accuracy: 0.9328

# %% [markdown]
# ## Predict

# %%
y_pred_cnn, y_pred_real = annModels.predictAnnModel(model_cnn,X_test,y_test,threshold = 0.5)
y_train_cnn,y_train_binary = annModels.predictAnnModel(model_cnn,X_train,y_train,threshold = 0.5)
y_val_cnn,y_train_binary = annModels.predictAnnModel(model_cnn,X_val,y_val,threshold = 0.5)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Graphs

# %%
data_visualization.plotAll(y_test, y_pred_cnn,y_pred_real, history_cnn, labels=[0, 1], title='Confusion matrix CNN',save = True)
# Out:
# AUC Score: 0.9189676672408937
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88     57489
#            1       0.88      0.84      0.86     52790
#
#     accuracy                           0.87    110279
#    macro avg       0.87      0.87      0.87    110279
# weighted avg       0.87      0.87      0.87    110279

# %% [markdown]
# # CNN on square

# %% [markdown]
# ## Model

# %%
X_train.shape
# Out:
# (246766, 41)

# %%
def pad_and_reshape(x):
    # Calculate padding size
    pad_size = np.ceil(float(x.size) / 49).astype(int) * 49 - x.size
    # Apply padding
    x_padded = np.pad(x, (0, pad_size), 'constant')
    # Reshape
    return x_padded.reshape(7, 7)

X_train_cnn = X_train.apply(pad_and_reshape, axis=1)
X_train_cnn = np.stack(X_train_cnn)
X_test_cnn = X_test.apply(pad_and_reshape, axis=1)
X_test_cnn = np.stack(X_test_cnn)
try:
  X_val_cnn = X_val.apply(pad_and_reshape, axis=1)
  X_val_cnn = np.stack(X_val_cnn)
except:
  pass

# %%
X_train_cnn.shape,X_val_cnn.shape,X_test_cnn.shape
# Out:
# ((246766, 7, 7), (61692, 7, 7), (110279, 7, 7))

# %%
X_train_cnn[0]
# Out:
# array([[-1.1847029 , -0.56566304, -1.394825  , -0.72789645, -0.50415283,
#         -1.5725728 , -1.2209892 ],
#        [ 0.1496792 , -1.1999503 ,  4.        ,  7.        , -0.5595381 ,
#         -0.5387952 ,  1.012127  ],
#        [-0.44306302, -0.6964819 , -1.0757111 ,  0.1763451 , -0.679352  ,
#         -0.54098403,  0.        ],
#        [ 0.6114295 ,  0.56184363,  0.83256143, -0.6354969 , -0.44243923,
#         -0.8432492 ,  5.56256   ],
#        [-1.1822516 ,  0.31649184, -0.21066588, -0.24576332, -1.6875591 ,
#          1.8192737 , -0.70624095],
#        [-0.6088661 , -0.76727057, -0.6194924 , -1.3456538 , -0.5534246 ,
#          0.05369875,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ]], dtype=float32)

# %%
# Check the input shape of your model
input_shape = model_cnn.layers[0].input_shape
print("Model input shape:", input_shape)

# Check the shape of your data
print("Training data shape:", X_train_cnn.shape)
print("Validation data shape:", X_val_cnn.shape)
# Out:
# Model input shape: (None, 41, 1)
# Training data shape: (246766, 7, 7)
# Validation data shape: (61692, 7, 7)

# %%
X_train_cnn = np.expand_dims(X_train_cnn, axis=-1)
X_test_cnn = np.expand_dims(X_test_cnn, axis=-1)
X_val_cnn = np.expand_dims(X_val_cnn, axis=-1)

print("New training data shape:", X_train_cnn.shape)
print("New validation data shape:", X_val_cnn.shape)
# Out:
# New training data shape: (246766, 7, 7, 1)
# New validation data shape: (61692, 7, 7, 1)

# %%
def get_cnn_model(input_shape):
    input_shape = (input_shape[0],input_shape[1], 1)
    
    model = Sequential()
    model.add(Conv2D(128, kernel_size=(2,2), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=3, strides=2, padding='same'))
    #Flatten
    model.add(Flatten())
    

    # fully connected layer
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.2))

    # output layer
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])
    # model.compile(optimizer='RMSprop', loss='binary_crossentropy', metrics=['accuracy'])

    # Print the model summary
    print(model.summary())

    return model

model_cnn =get_cnn_model((X_train_cnn.shape[1],X_train_cnn.shape[2]))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 6, 6, 128)         640
#
#  batch_normalization_3 (Bat  (None, 6, 6, 128)         512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 128)         0
#
#  max_pooling2d (MaxPooling2  (None, 3, 3, 128)         0
#  D)
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_9 (Dense)             (None, 100)               115300
#
#  dropout_5 (Dropout)         (None, 100)               0
#
#  dense_10 (Dense)            (None, 100)               10100
#
#  dropout_6 (Dropout)         (None, 100)               0
#
#  dense_11 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 126653 (494.74 KB)
# Trainable params: 126397 (493.74 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# None

# %%
history_cnn = model_cnn.fit(X_train_cnn, y_train, validation_data=(X_val_cnn, y_val), epochs=60, batch_size=2048)
# Out:
# Epoch 1/60
# 121/121 [==============================] - 6s 42ms/step - loss: 0.5738 - accuracy: 0.7010 - val_loss: 0.5640 - val_accuracy: 0.6765
# Epoch 2/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.4137 - accuracy: 0.8086 - val_loss: 0.4468 - val_accuracy: 0.7753
# Epoch 3/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.3661 - accuracy: 0.8351 - val_loss: 0.3761 - val_accuracy: 0.8267
# Epoch 4/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.3384 - accuracy: 0.8502 - val_loss: 0.3102 - val_accuracy: 0.8643
# Epoch 5/60
# 121/121 [==============================] - 5s 39ms/step - loss: 0.3221 - accuracy: 0.8578 - val_loss: 0.2911 - val_accuracy: 0.8704
# Epoch 6/60
# 121/121 [==============================] - 5s 39ms/step - loss: 0.3107 - accuracy: 0.8635 - val_loss: 0.2847 - val_accuracy: 0.8765
# Epoch 7/60
# 121/121 [==============================] - 5s 41ms/step - loss: 0.3018 - accuracy: 0.8677 - val_loss: 0.2771 - val_accuracy: 0.8782
# Epoch 8/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.2971 - accuracy: 0.8700 - val_loss: 0.2883 - val_accuracy: 0.8775
# Epoch 9/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.2930 - accuracy: 0.8728 - val_loss: 0.2766 - val_accuracy: 0.8811
# Epoch 10/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.
60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.2588 - accuracy: 0.8817 - val_loss: 0.2376 - val_accuracy: 0.8925
# Epoch 58/60
# 121/121 [==============================] - 5s 38ms/step - loss: 0.2552 - accuracy: 0.8832 - val_loss: 0.2324 - val_accuracy: 0.9008
# Epoch 59/60
# 121/121 [==============================] - 5s 39ms/step - loss: 0.2542 - accuracy: 0.8845 - val_loss: 0.2328 - val_accuracy: 0.8990
# Epoch 60/60
# 121/121 [==============================] - 5s 40ms/step - loss: 0.2573 - accuracy: 0.8832 - val_loss: 0.2421 - val_accuracy: 0.8948

# %% [markdown]
# ## Predict

# %%
y_pred_cnn2d, y_pred_real = annModels.predictAnnModel(model_cnn,X_test_cnn,y_test,threshold = 0.5)
y_train_cnn2d, y_train_binary = annModels.predictAnnModel(model_cnn,X_train_cnn,y_train,threshold = 0.5)
y_val_cnn2d, y_val_binary = annModels.predictAnnModel(model_cnn,X_val_cnn,y_val,threshold = 0.5)
# Out:
# 3447/3447 [==============================] - 9s 3ms/step
# 0.8282447247436049
# 3447/3447 [==============================] - 10s 3ms/step - loss: 5.3676 - accuracy: 0.8282
# 5.367638111114502 0.8282447457313538
# 7712/7712 [==============================] - 21s 3ms/step
# 0.8972103126038433
# 7712/7712 [==============================] - 23s 3ms/step - loss: 0.2375 - accuracy: 0.8972
# 0.2375050187110901 0.8972102999687195
# 1928/1928 [==============================] - 6s 3ms/step
# 0.8948323931790183
# 1928/1928 [==============================] - 6s 3ms/step - loss: 0.2421 - accuracy: 0.8948
# 0.24209564924240112 0.8948323726654053

# %% [markdown]
# ## Graphs

# %%
data_visualization.plotAll(y_test, y_pred_cnn2d, y_pred_real, history_cnn, labels=[0, 1], title='Confusion matrix CNN')
# Out:
# AUC Score: 0.8842170834457073
#               precision    recall  f1-score   support
#
#            0       0.78      0.93      0.85     57489
#            1       0.91      0.71      0.80     52790
#
#     accuracy                           0.83    110279
#    macro avg       0.84      0.82      0.82    110279
# weighted avg       0.84      0.83      0.83    110279

# %% [markdown]
# # Lightgbm

# %%
# use lightgdm model
import lightgbm as lgb

# %%
train_data = lgb.Dataset(X_train, label=y_train)
val_data = lgb.Dataset(X_val, label=y_val)

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'binary_logloss',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# %%
gbm = lgb.train(params, train_data, num_boost_round=20)

# Predict on test set

# %%
y_pred = gbm.predict(X_test, num_iteration=gbm.best_iteration)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_pred.round()))
# Out:
# 0.8006238721787466

# %% [markdown]
# # Ensemble Hetergeneous

# %%
#create a dataframe to store y_pred_ann,y_pred_xgboost,y_pred_cnn2d,y_pred_cnn
X_meta_test = pd.DataFrame({'y_pred_ann':y_pred_ann,'y_pred_xgboost':y_pred_xgboost,'y_pred_cnn2d':y_pred_cnn2d,'y_pred_cnn':y_pred_cnn})
y_meta_test = y_test

X_meta_train = pd.DataFrame({'y_pred_ann':y_train_ann,'y_pred_xgboost':y_train_xgboost,'y_pred_cnn2d':y_train_cnn2d,'y_pred_cnn':y_train_cnn})
y_meta_train = y_train


# create a model to stack the models
def get_meta_model(input_shape):
    model = Sequential()
    model.add(Dense(100, input_dim=input_shape, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
  
meta_model = get_meta_model(X_meta_train.shape[1])

# %%
history_meta = meta_model.fit(X_meta_train, y_meta_train, epochs=100, batch_size=2048)

# %%
y_pred_meta, y_pred_binary = annModels.predictAnnModel(model,X_test,y_test,threshold = 0.5)

# %%
# confusion matrix    
data_visualization.plotAll(y_test, y_pred_meta,y_pred_binary, history, labels=[0, 1], title='Confusion matrix Meta Classifier')
